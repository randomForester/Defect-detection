# %%
import PIL
from PIL import Image

# %%
basewidth = 500
img = Image.open("/Users/cesare.chung/int/01_CODE_UNET/NEW/trainData_tftf/resize/1.gif")
img.size
# Out:
# (565, 584)

# %%
wpercent = (basewidth / float(img.size[0]))
hsize = int((float(img.size[1]) * float(wpercent)))
img = img.resize((basewidth, hsize), PIL.Image.ANTIALIAS)
img.save("/Users/cesare.chung/int/01_CODE_UNET/NEW/trainData_tftf/resize/1_resized_image.gif")

# %%
#img.crop
img.size
# Out:
# (500, 516)

# %%
img
# Out:
# <PIL.Image.Image image mode=L size=500x516 at 0x10861D400>

# %%
import glob

DATA_ROOT = "/Users/cesare.chung/int/01_CODE_UNET/NEW/"

masks_dir = sorted(glob.glob(DATA_ROOT+"/trainData_tf2/*_mask.gif"))

basewidth = 500
Y_data=[]
for index,entry in enumerate(masks_dir):
    img = Image.open(entry)
    wpercent = (basewidth / float(img.size[0]))
    hsize = int((float(img.size[1]) * float(wpercent)))
    img = img.resize((basewidth, hsize), PIL.Image.ANTIALIAS)
    Y_data.append(img)

# %%
Y_data[2]
# Out:
# <PIL.Image.Image image mode=L size=500x516 at 0x108B2AEF0>

# %%
Y_data
# Out:
# [<PIL.Image.Image image mode=L size=500x516 at 0x10861DCF8>,
#  <PIL.Image.Image image mode=L size=500x516 at 0x108B2AF60>,
#  <PIL.Image.Image image mode=L size=500x516 at 0x108B2AEF0>,
#  <PIL.Image.Image image mode=L size=500x516 at 0x108C92320>,
#  <PIL.Image.Image image mode=L size=500x516 at 0x108C92400>,
#  <PIL.Image.Image image mode=L size=500x516 at 0x108C92438>,
#  <PIL.Image.Image image mode=L size=500x516 at 0x108C92470>,
#  <PIL.Image.Image image mode=L size=500x516 at 0x108C924A8>,
#  <PIL.Image.Image image mode=L size=500x516 at 0x108C924E0>,
#  <PIL.Image.Image image mode=L size=500x516 at 0x108C92518>,
#  <PIL.Image.Image image mode=L size=500x516 at 0x108C92550>,
#  <PIL.Image.Image image mode=L size=500x516 at 0x108C92588>,
#  <PIL.Image.Image image mode=L size=500x516 at 0x108C925C0>,
#  <PIL.Image.Image image mode=L size=500x516 at 0x108C925F8>,
#  <PIL.Image.Image image mode=L size=500x516 at 0x108C92630>,
# ...

# %%
Y_data[1].size
# Out:
# (500, 516)

# %%
Y_data[0].save("/Users/cesare.chung/int/01_CODE_UNET/NEW/trainData_tftf/resize/21_mask.gif")
Y_data[1].save("/Users/cesare.chung/int/01_CODE_UNET/NEW/trainData_tftf/resize/22_mask.gif")
Y_data[2].save("/Users/cesare.chung/int/01_CODE_UNET/NEW/trainData_tftf/resize/23_mask.gif")
Y_data[3].save("/Users/cesare.chung/int/01_CODE_UNET/NEW/trainData_tftf/resize/24_mask.gif")
Y_data[4].save("/Users/cesare.chung/int/01_CODE_UNET/NEW/trainData_tftf/resize/25_mask.gif")

# %%
for i in range(0,20):
    print(Y_data[i].size)
# Out:
# (500, 516)
# (500, 516)
# (500, 516)
# (500, 516)
# (500, 516)
# (500, 516)
# (500, 516)
# (500, 516)
# (500, 516)
# (500, 516)
# (500, 516)
# (500, 516)
# (500, 516)
# (500, 516)
# (500, 516)
# (500, 516)
# (500, 516)
# (500, 516)
# (500, 516)
# (500, 516)

# %%
for i in [1,19]:
    print(Y_data[i].size)
# Out:
# (500, 516)
# (500, 516)
