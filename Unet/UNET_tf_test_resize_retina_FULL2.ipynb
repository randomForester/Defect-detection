# %%
from tf_unet import unet, util, image_util
import glob
import cv2
import matplotlib.pyplot as plt
import numpy as np
#import scipy
from scipy import misc
# %matplotlib inline

# %%
#DATA_ROOT = "/Users/cesare.chung/int/01_CODE_UNET/NEW/"
#DATA_ROOT = "/Users/chung/int/"
DATA_ROOT = "D:/Cesare/tf_UNET_int/NEW/"

#masks_dir = sorted(glob.glob(DATA_ROOT+"/trainData_tftf/resize/*_mask.gif"))
#imgs_dir  = sorted(glob.glob(DATA_ROOT+"/trainData_tftf/resize/*_training.tif"))

masks_dir = sorted(glob.glob(DATA_ROOT+"/trainData_tftf/resize2/*_mask_resized_mask.gif"))
imgs_dir  = sorted(glob.glob(DATA_ROOT+"/trainData_tftf/resize2/*_training_resized_training.tif"))

# %%
X_data=[]
for index,entry in enumerate(imgs_dir):
    img = misc.imread(entry)
    X_data.append(img)

Y_data=[]
for index,entry in enumerate(masks_dir):
    img = misc.imread(entry)
    Y_data.append(img)

X_data=np.array(X_data)
Y_data=np.array(Y_data)

plt.imshow(X_data[4,...,2], aspect="auto")   # X_data[i,...,j]. i = 1,..., number of samples; j = 1,2,3
plt.show()
plt.imshow(Y_data[4,...,], aspect="auto",cmap='gray')
plt.show()

# %%
#preparing data loading

#data_provider = image_util.ImageDataProvider(DATA_ROOT+"/trainData_tf/*.jpg", data_suffix="_img.jpg", mask_suffix="_mask.jpg")
#data_provider.n_class = 2

#data_provider = image_util.ImageDataProvider(DATA_ROOT+"/trainData_tftf/resize/*",data_suffix="_training.tif", mask_suffix="_mask.gif")
data_provider = image_util.ImageDataProvider(DATA_ROOT+"/trainData_tftf/resize2/*",data_suffix="_training_resized_training.tif", mask_suffix="_mask_resized_mask.gif")
#data_provider.n_class = 2

#search_path = DATA_ROOT+"/trainData_tf2/*"
#data_provider = image_util.ImageDataProvider(search_path, a_min=0, a_max=255, data_suffix="_training.tif", mask_suffix="_mask.gif")
#data_provider.n_class = 2
# Out:
# Number of files used: 20

# %%
x_test, y_test = data_provider(1)

fig, ax = plt.subplots(1,2, sharey=True, figsize=(8,4))
ax[0].imshow(x_test[0,...,0], aspect="auto")
ax[1].imshow(y_test[0,...,1], aspect="auto")
plt.show()

# %%
print(x_test.shape)
print(y_test.shape)

print(data_provider.channels)
print(data_provider.n_class)
# Out:
# (1, 550, 550, 3)
# (1, 550, 550, 2)
# 3
# 2

# %%
#setup & training

#net = unet.Unet(layers=3, features_root=64, channels=3, n_class=2)

net = unet.Unet(channels=data_provider.channels, n_class=data_provider.n_class, layers=3, features_root=64)
trainer = unet.Trainer(net, optimizer="adam")

#net = unet.Unet(channels=data_provider.channels,n_class=data_provider.n_class)
#trainer = unet.Trainer(net, optimizer="momentum", opt_kwargs=dict(momentum=0.2))

#z,y=data_provider(1)
# Out:
# 2017-10-31 11:31:05,954 Layers 3, features 64, filter size 3x3, pool size: 2x2

# %%
path = trainer.train(data_provider, output_path="out", training_iters=32, epochs=10,dropout=0.75, display_step=5)
# Out:
# 2017-10-31 11:31:25,874 Removing 'D:\Cesare\tf_UNET_int\prediction'
# 2017-10-31 11:31:25,878 Removing 'D:\Cesare\tf_UNET_int\out'
# 2017-10-31 11:31:25,885 Allocating 'D:\Cesare\tf_UNET_int\prediction'
# 2017-10-31 11:31:25,886 Allocating 'D:\Cesare\tf_UNET_int\out'
# 2017-10-31 11:32:22,832 Verification error= 83.0%, loss= 0.7114
# 2017-10-31 11:32:36,500 Start optimization
# 2017-10-31 11:33:10,285 Iter 0, Minibatch Loss= 0.6066, Training Accuracy= 0.8044, Minibatch error= 19.6%
# 2017-10-31 11:33:25,829 Iter 5, Minibatch Loss= 0.5587, Training Accuracy= 0.7647, Minibatch error= 23.5%
# 2017-10-31 11:33:42,360 Iter 10, Minibatch Loss= 0.4630, Training Accuracy= 0.8166, Minibatch error= 18.3%
# 2017-10-31 11:33:59,143 Iter 15, Minibatch Loss= 0.4605, Training Accuracy= 0.8166, Minibatch error= 18.3%
# 2017-10-31 11:34:14,425 Iter 20, Minibatch Loss= 0.4517, Training Accuracy= 0.7899, Minibatch error= 21.0%
# 2017-10-31 11:34:29,464 Iter 25, Minibatch Loss= 0.4847, Training Accuracy= 0.7827, Minibatch error= 21.7%
# 2017-10-31 11:34:46,729 Iter 30, Minibatch Loss= 0.4614, Training Accuracy= 0.7932, Minibatch error= 20.7%
# 2017-10-31 11:34:49,659 Epoch 0, Average loss: 0.4892, learning rate: 0.0010
# 2017-10-31 11:34:51,969 Verification error= 17.0%, loss= 0.4259
# 2017-10-31 11:35:14,296 Iter 35, Minibatch Loss= 0.4467, Training Accuracy= 0.8109, Minibatch error= 18.9%
# 2017-10-31 11:35:29,548 Iter 40, Minibatch Loss= 0.4757, Training Accuracy= 0.7827, Minibatch error= 21.7%
# 2017-10-31 11:35:44,317 Iter 45, Minibatch Loss= 0.4535, Training Accuracy= 0.8044, Minibatch error= 19.6%
# 2017-10-31 11:36:02,107 Iter 50, Minibatch Loss= 0.4419, Training Accuracy= 0.8063, Minibatch error= 19.4%
# 2017-10-31 11:36:20,239 Iter 55, Minibatch Loss= 0.4067, Training Accuracy= 0.8584, Minibatch error= 14.2%
# 2017-10-31 11:36:38,755 Iter 60, Minibatch Loss= 0.4859, Training Accuracy= 0.7647, Minibatch error= 23.5%
# 2017-10-31 11:36:46,932 Epoch 1, Average loss: 0.4478, learning rate: 0.0010
# 2017-10-31 11:36:49,696 Verification error= 17.0%, loss= 0.4406
# 2017-10-31 11:37:03,913 Iter 65, Minibatch Loss= 0.4652, Training Accuracy= 0.7936, Minibatch error= 20.6%
# 2017-10-31 11:37:21,486 Iter 70, Minibatch Loss= 0.4455, Training Accuracy= 0.8121, Minibatch error= 18.8%
# 2017-10-31 11:37:38,397 Iter 75, Minibatch Loss= 0.4593, Training Accuracy= 0.7936, Minibatch error= 20.6%
# 2017-10-31 11:37:54,884 Iter 80, Minibatch Loss= 0.4422, Training Accuracy= 0.8109, Minibatch error= 18.9%
# 2017-10-31 11:38:11,193 Iter 85, Minibatch Loss= 0.4508, Training Accuracy= 0.8063, Minibatch error= 19.4%
# 2017-10-31 11:38:28,775 Iter 90, Minibatch Loss= 0.4341, Training Accuracy= 0.8247, Minibatch error= 17.5%
# 2017-10-31 11:38:44,413 Iter 95, Minibatch Loss= 0.4566, Training Accuracy= 0.8051, Minibatch error= 19.5%
# 2017-10-31 11:38:44,414 Epoch 2, Average loss: 0.4435, learning rate: 0.0010
# 2017-10-31 11:38:46,770 Verification error= 17.0%, loss= 0.4373
# 2017-10-31 11:39:11,790 Iter 100, Minibatch Loss= 0.4538, Training Accuracy= 0.8063, Minibatch error= 19.4%
# 2017-10-31 11:39:29,076 Iter 105, Minibatch Loss= 0.3941, Training Accuracy= 0.8635, Minibatch error= 13.7%
# 2017-10-31 11:39:46,433 Iter 110, Minibatch Loss= 0.4713, Training Accuracy= 0.7827, Minibatch error= 21.7%
# 2017-10-31 11:40:01,025 Iter 115, Minibatch Loss= 0.4589, Training Accuracy= 0.8109, Minibatch error= 18.9%
# 2017-10-31 11:40:16,673 Iter 120, Minibatch Loss= 0.4586, Training Accuracy= 0.7936, Minibatch error= 20.6%
# 2017-10-31 11:40:33,975 Iter 125, Minibatch Loss= 0.4546, Training Accuracy= 0.8051, Minibatch error= 19.5%
# 2017-10-31 11:40:39,431 Epoch 3, Average loss: 0.4448, learning rate: 0.0010
# 2017-10-31 11:40:42,201 Verification error= 17.0%, loss= 0.4352
# 2017-10-31 11:41:02,234 Iter 130, Minibatch Loss= 0.4612, Training Accuracy= 0.7899, Minibatch error= 21.0%
# 2017-10-31 11:41:19,323 Iter 135, Minibatch Loss= 0.4597, Training Accuracy= 0.7899, Minibatch error= 21.0%
# 2017-10-31 11:41:36,103 Iter 140, Minibatch Loss= 0.4423, Training Accuracy= 0.8121, Minibatch error= 18.8%
# 2017-10-31 11:41:53,225 Iter 145, Minibatch Loss= 0.4566, Training Accuracy= 0.8063, Minibatch error= 19.4%
# 2017-10-31 11:42:09,225 Iter 150, Minibatch Loss= 0.4520, Training Accuracy= 0.8044, Minibatch error= 19.6%
# 2017-10-31 11:42:25,238 Iter 155, Minibatch Loss= 0.4833, Training Accuracy= 0.7647, Minibatch error= 23.5%
# 2017-10-31 11:42:36,312 Epoch 4, Average loss: 0.4437, learning rate: 0.0010
# 2017-10-31 11:42:38,782 Verification error= 17.0%, loss= 0.4394
# 2017-10-31 11:42:54,805 Iter 160, Minibatch Loss= 0.4957, Training Accuracy= 0.7503, Minibatch error= 25.0%
# 2017-10-31 11:43:12,943 Iter 165, Minibatch Loss= 0.4603, Training Accuracy= 0.7932, Minibatch error= 20.7%
# 2017-10-31 11:43:28,565 Iter 170, Minibatch Loss= 0.4296, Training Accuracy= 0.8247, Minibatch error= 17.5%
# 2017-10-31 11:43:45,018 Iter 175, Minibatch Loss= 0.4510, Training Accuracy= 0.8206, Minibatch error= 17.9%
# 2017-10-31 11:44:04,418 Iter 180, Minibatch Loss= 0.4621, Training Accuracy= 0.8051, Minibatch error= 19.5%
# 2017-10-31 11:44:23,980 Iter 185, Minibatch Loss= 0.4003, Training Accuracy= 0.8635, Minibatch error= 13.7%
# 2017-10-31 11:44:40,803 Iter 190, Minibatch Loss= 0.4407, Training Accuracy= 0.8109, Minibatch error= 18.9%
# 2017-10-31 11:44:43,800 Epoch 5, Average loss: 0.4411, learning rate: 0.0010
# 2017-10-31 11:44:46,495 Verification error= 17.0%, loss= 0.4280
# 2017-10-31 11:45:13,277 Iter 195, Minibatch Loss= 0.4636, Training Accuracy= 0.7899, Minibatch error= 21.0%
# 2017-10-31 11:45:28,938 Iter 200, Minibatch Loss= 0.4706, Training Accuracy= 0.7894, Minibatch error= 21.1%
# 2017-10-31 11:45:46,390 Iter 205, Minibatch Loss= 0.4901, Training Accuracy= 0.7503, Minibatch error= 25.0%
# 2017-10-31 11:46:05,225 Iter 210, Minibatch Loss= 0.3936, Training Accuracy= 0.8635, Minibatch error= 13.7%
# 2017-10-31 11:46:23,916 Iter 215, Minibatch Loss= 0.3849, Training Accuracy= 0.8635, Minibatch error= 13.7%
# 2017-10-31 11:46:39,286 Iter 220, Minibatch Loss= 0.4627, Training Accuracy= 0.7932, Minibatch error= 20.7%
# 2017-10-31 11:46:47,646 Epoch 6, Average loss: 0.4379, learning rate: 0.0010
# 2017-10-31 11:46:50,329 Verification error= 17.0%, loss= 0.4342
# 2017-10-31 11:47:08,649 Iter 225, Minibatch Loss= 0.4456, Training Accuracy= 0.8083, Minibatch error= 19.2%
# 2017-10-31 11:47:25,413 Iter 230, Minibatch Loss= 0.4345, Training Accuracy= 0.8276, Minibatch error= 17.2%
# 2017-10-31 11:47:43,138 Iter 235, Minibatch Loss= 0.4280, Training Accuracy= 0.8276, Minibatch error= 17.2%
# 2017-10-31 11:48:01,213 Iter 240, Minibatch Loss= 0.4402, Training Accuracy= 0.8247, Minibatch error= 17.5%
# 2017-10-31 11:48:19,820 Iter 245, Minibatch Loss= 0.4572, Training Accuracy= 0.8083, Minibatch error= 19.2%
# 2017-10-31 11:48:37,384 Iter 250, Minibatch Loss= 0.4493, Training Accuracy= 0.8063, Minibatch error= 19.4%
# 2017-10-31 11:48:54,662 Iter 255, Minibatch Loss= 0.4328, Training Accuracy= 0.8166, Minibatch error= 18.3%
# 2017-10-31 11:48:54,662 Epoch 7, Average loss: 0.4436, learning rate: 0.0010
# 2017-10-31 11:48:57,201 Verification error= 17.0%, loss= 0.4142
# 2017-10-31 11:49:33,152 Iter 260, Minibatch Loss= 0.4828, Training Accuracy= 0.8051, Minibatch error= 19.5%
# 2017-10-31 11:49:49,754 Iter 265, Minibatch Loss= 0.4322, Training Accuracy= 0.8276, Minibatch error= 17.2%
# 2017-10-31 11:50:05,770 Iter 270, Minibatch Loss= 0.4725, Training Accuracy= 0.8206, Minibatch error= 17.9%
# 2017-10-31 11:50:22,314 Iter 275, Minibatch Loss= 0.4549, Training Accuracy= 0.8051, Minibatch error= 19.5%
# 2017-10-31 11:50:37,245 Iter 280, Minibatch Loss= 0.4721, Training Accuracy= 0.7827, Minibatch error= 21.7%
# 2017-10-31 11:50:54,600 Iter 285, Minibatch Loss= 0.4731, Training Accuracy= 0.8063, Minibatch error= 19.4%
# 2017-10-31 11:51:00,088 Epoch 8, Average loss: 0.4537, learning rate: 0.0010
# 2017-10-31 11:51:02,818 Verification error= 17.0%, loss= 0.4495
# 2017-10-31 11:51:28,327 Iter 290, Minibatch Loss= 0.4460, Training Accuracy= 0.8063, Minibatch error= 19.4%
# 2017-10-31 11:51:49,403 Iter 295, Minibatch Loss= 0.4515, Training Accuracy= 0.7899, Minibatch error= 21.0%
# 2017-10-31 11:52:06,518 Iter 300, Minibatch Loss= 0.4732, Training Accuracy= 0.7894, Minibatch error= 21.1%
# 2017-10-31 11:52:26,235 Iter 305, Minibatch Loss= 0.4515, Training Accuracy= 0.8063, Minibatch error= 19.4%
# 2017-10-31 11:52:45,580 Iter 310, Minibatch Loss= 0.4528, Training Accuracy= 0.8109, Minibatch error= 18.9%
# 2017-10-31 11:53:03,592 Iter 315, Minibatch Loss= 0.4019, Training Accuracy= 0.8635, Minibatch error= 13.7%
# 2017-10-31 11:53:14,920 Epoch 9, Average loss: 0.4358, learning rate: 0.0010
# 2017-10-31 11:53:17,785 Verification error= 17.0%, loss= 0.4279
# 2017-10-31 11:53:35,251 Optimization Finished!

# %%
x_test, y_test = data_provider(1)

# %%
prediction = net.predict("./out/model.cpkt", x_test)
# Out:
# INFO:tensorflow:Restoring parameters from ./out/model.cpkt
# 2017-10-31 11:54:20,316 Restoring parameters from ./out/model.cpkt
# 2017-10-31 11:54:23,058 Model restored from file: ./out/model.cpkt

# %%
fig, ax = plt.subplots(1, 3, sharex=True, sharey=True, figsize=(12,5))
ax[0].imshow(x_test[0,...,0], aspect="auto")
ax[1].imshow(y_test[0,...,1], aspect="auto")
mask = prediction[0,...,1] > 0.9
ax[2].imshow(mask, aspect="auto")
ax[0].set_title("Input")
ax[1].set_title("Ground truth")
ax[2].set_title("Prediction")
fig.tight_layout()

plt.show()

# %%
unet.error_rate(prediction, util.crop_to_shape(y_test, prediction.shape))
# Out:
# 18.343124186248374

# %%
img = util.combine_img_prediction(x_test,y_test,prediction)
util.save_image(img, "D:/Cesare/tf_UNET_int/retina_problem.png")

#util.save_image(img, "/Users/chung/int/retina_problem.png")
