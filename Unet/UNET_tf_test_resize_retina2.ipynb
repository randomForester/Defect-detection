# %%
from tf_unet import unet, util, image_util
import glob
import cv2
import matplotlib.pyplot as plt
import numpy as np
#import scipy
from scipy import misc
# %matplotlib inline

# %%
#DATA_ROOT = "/Users/cesare.chung/int/01_CODE_UNET/NEW/"
DATA_ROOT = "/Users/chung/int/"

masks_dir = sorted(glob.glob(DATA_ROOT+"/trainData_tftf/resize/*_mask.gif"))
imgs_dir  = sorted(glob.glob(DATA_ROOT+"/trainData_tftf/resize/*_training.tif"))

# %%
X_data=[]
for index,entry in enumerate(imgs_dir):
    img = misc.imread(entry)
    X_data.append(img)

Y_data=[]
for index,entry in enumerate(masks_dir):
    img = misc.imread(entry)
    Y_data.append(img)

X_data=np.array(X_data)
Y_data=np.array(Y_data)

plt.imshow(X_data[4,...,2], aspect="auto")   # X_data[i,...,j]. i = 1,..., number of samples; j = 1,2,3
plt.show()
plt.imshow(Y_data[4,...,], aspect="auto",cmap='gray')
plt.show()

# %%
#preparing data loading

#data_provider = image_util.ImageDataProvider(DATA_ROOT+"/trainData_tf/*.jpg", data_suffix="_img.jpg", mask_suffix="_mask.jpg")
#data_provider.n_class = 2

data_provider = image_util.ImageDataProvider(DATA_ROOT+"/trainData_tftf/resize/*",data_suffix="_training.tif", mask_suffix="_mask.gif")
#data_provider.n_class = 2

#search_path = DATA_ROOT+"/trainData_tf2/*"
#data_provider = image_util.ImageDataProvider(search_path, a_min=0, a_max=255, data_suffix="_training.tif", mask_suffix="_mask.gif")
#data_provider.n_class = 2
# Out:
# Number of files used: 5

# %%
x_test, y_test = data_provider(1)

fig, ax = plt.subplots(1,2, sharey=True, figsize=(8,4))
ax[0].imshow(x_test[0,...,0], aspect="auto")
ax[1].imshow(y_test[0,...,1], aspect="auto")
plt.show()

# %%
print(x_test.shape)
print(y_test.shape)

print(data_provider.channels)
print(data_provider.n_class)
# Out:
# (1, 516, 500, 3)
# (1, 516, 500, 2)
# 3
# 2

# %%
#setup & training

#net = unet.Unet(layers=3, features_root=64, channels=3, n_class=2)

net = unet.Unet(channels=data_provider.channels, n_class=data_provider.n_class, layers=3, features_root=64)
trainer = unet.Trainer(net, optimizer="adam")

#net = unet.Unet(channels=data_provider.channels,n_class=data_provider.n_class)
#trainer = unet.Trainer(net, optimizer="momentum", opt_kwargs=dict(momentum=0.2))

#z,y=data_provider(1)
# Out:
# 2017-10-30 21:17:51,095 Layers 3, features 64, filter size 3x3, pool size: 2x2

# %%
path = trainer.train(data_provider, output_path="out", training_iters=20, epochs=3,dropout=0.75, display_step=2)
# Out:
# 2017-10-30 21:19:27,621 Removing '/Users/chung/int/01_Face/prediction'
# 2017-10-30 21:19:27,623 Removing '/Users/chung/int/01_Face/out'
# 2017-10-30 21:19:27,624 Allocating '/Users/chung/int/01_Face/prediction'
# 2017-10-30 21:19:27,626 Allocating '/Users/chung/int/01_Face/out'
# 2017-10-30 21:20:57,107 Verification error= 79.8%, loss= 0.7105
# 2017-10-30 21:21:03,886 Start optimization
# 2017-10-30 21:22:22,593 Iter 0, Minibatch Loss= 0.6222, Training Accuracy= 0.8550, Minibatch error= 14.5%
# 2017-10-30 21:24:26,121 Iter 2, Minibatch Loss= 0.6500, Training Accuracy= 0.7376, Minibatch error= 26.2%
# 2017-10-30 21:26:14,331 Iter 4, Minibatch Loss= 0.5831, Training Accuracy= 0.7826, Minibatch error= 21.7%
# 2017-10-30 21:28:06,395 Iter 6, Minibatch Loss= 0.6164, Training Accuracy= 0.7376, Minibatch error= 26.2%
# 2017-10-30 21:29:53,571 Iter 8, Minibatch Loss= 0.5765, Training Accuracy= 0.8186, Minibatch error= 18.1%
# 2017-10-30 21:31:43,378 Iter 10, Minibatch Loss= 0.5958, Training Accuracy= 0.7376, Minibatch error= 26.2%
# 2017-10-30 21:33:34,667 Iter 12, Minibatch Loss= 0.5435, Training Accuracy= 0.7826, Minibatch error= 21.7%
# 2017-10-30 21:35:22,325 Iter 14, Minibatch Loss= 0.4377, Training Accuracy= 0.8550, Minibatch error= 14.5%
# 2017-10-30 21:37:08,619 Iter 16, Minibatch Loss= 0.5201, Training Accuracy= 0.7771, Minibatch error= 22.3%
# 2017-10-30 21:39:05,520 Iter 18, Minibatch Loss= 0.4024, Training Accuracy= 0.8550, Minibatch error= 14.5%
# 2017-10-30 21:40:04,576 Epoch 0, Average loss: 0.5654, learning rate: 0.0010
# 2017-10-30 21:41:25,515 Verification error= 20.2%, loss= 0.4853
# 2017-10-30 21:42:43,437 Iter 20, Minibatch Loss= 0.5076, Training Accuracy= 0.7771, Minibatch error= 22.3%
# 2017-10-30 21:44:44,742 Iter 22, Minibatch Loss= 0.4204, Training Accuracy= 0.8550, Minibatch error= 14.5%
# 2017-10-30 21:46:50,165 Iter 24, Minibatch Loss= 0.4952, Training Accuracy= 0.7826, Minibatch error= 21.7%
# 2017-10-30 21:48:52,806 Iter 26, Minibatch Loss= 0.4399, Training Accuracy= 0.8550, Minibatch error= 14.5%
# 2017-10-30 21:55:53,212 Iter 28, Minibatch Loss= 0.5289, Training Accuracy= 0.7376, Minibatch error= 26.2%
# 2017-10-30 21:57:53,277 Iter 30, Minibatch Loss= 0.4411, Training Accuracy= 0.8550, Minibatch error= 14.5%
# 2017-10-30 22:00:04,818 Iter 32, Minibatch Loss= 0.4556, Training Accuracy= 0.8186, Minibatch error= 18.1%
# 2017-10-30 22:02:29,168 Iter 34, Minibatch Loss= 0.4888, Training Accuracy= 0.7771, Minibatch error= 22.3%
# 2017-10-30 22:04:51,612 Iter 36, Minibatch Loss= 0.4563, Training Accuracy= 0.8186, Minibatch error= 18.1%
# 2017-10-30 22:07:14,763 Iter 38, Minibatch Loss= 0.4458, Training Accuracy= 0.8550, Minibatch error= 14.5%
# 2017-10-30 22:08:14,275 Epoch 1, Average loss: 0.4835, learning rate: 0.0010
# 2017-10-30 22:09:36,917 Verification error= 20.2%, loss= 0.4745
# 2017-10-30 22:10:54,316 Iter 40, Minibatch Loss= 0.4901, Training Accuracy= 0.7771, Minibatch error= 22.3%
# 2017-10-30 22:13:09,043 Iter 42, Minibatch Loss= 0.4648, Training Accuracy= 0.8186, Minibatch error= 18.1%
# 2017-10-30 22:15:00,495 Iter 44, Minibatch Loss= 0.4616, Training Accuracy= 0.8550, Minibatch error= 14.5%
# 2017-10-30 22:16:48,461 Iter 46, Minibatch Loss= 0.4634, Training Accuracy= 0.8550, Minibatch error= 14.5%
# 2017-10-30 22:18:40,736 Iter 48, Minibatch Loss= 0.4831, Training Accuracy= 0.7826, Minibatch error= 21.7%
# 2017-10-30 22:20:29,862 Iter 50, Minibatch Loss= 0.4648, Training Accuracy= 0.8186, Minibatch error= 18.1%
# 2017-10-30 22:22:16,973 Iter 52, Minibatch Loss= 0.5103, Training Accuracy= 0.7376, Minibatch error= 26.2%
# 2017-10-30 22:24:15,676 Iter 54, Minibatch Loss= 0.4934, Training Accuracy= 0.7771, Minibatch error= 22.3%
# 2017-10-30 22:26:32,397 Iter 56, Minibatch Loss= 0.4661, Training Accuracy= 0.8550, Minibatch error= 14.5%
# 2017-10-30 22:29:15,151 Iter 58, Minibatch Loss= 0.4727, Training Accuracy= 0.8186, Minibatch error= 18.1%
# 2017-10-30 22:30:34,296 Epoch 2, Average loss: 0.4631, learning rate: 0.0010
# 2017-10-30 22:32:13,898 Verification error= 20.2%, loss= 0.4864
# 2017-10-30 22:32:27,079 Optimization Finished!

# %%
x_test, y_test = data_provider(1)

prediction = net.predict("./out/model.cpkt", x_test)
# Out:
# INFO:tensorflow:Restoring parameters from ./out/model.cpkt
# 2017-10-30 22:33:12,295 Restoring parameters from ./out/model.cpkt
# 2017-10-30 22:33:12,940 Model restored from file: ./out/model.cpkt

# %%
fig, ax = plt.subplots(1, 3, sharex=True, sharey=True, figsize=(12,5))
ax[0].imshow(x_test[0,...,0], aspect="auto")
ax[1].imshow(y_test[0,...,1], aspect="auto")
mask = prediction[0,...,1] > 0.9
ax[2].imshow(mask, aspect="auto")
ax[0].set_title("Input")
ax[1].set_title("Ground truth")
ax[2].set_title("Prediction")
fig.tight_layout()

plt.show()

# %%
unet.error_rate(prediction, util.crop_to_shape(y_test, prediction.shape))
# Out:
# 18.144866642309097

# %%
img = util.combine_img_prediction(x_test,y_test,prediction)
util.save_image(img, "/Users/chung/int/retina_problem.png")
