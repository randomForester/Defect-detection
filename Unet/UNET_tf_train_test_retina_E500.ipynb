# %%
from tf_unet import unet, util, image_util
import glob
import cv2
import matplotlib.pyplot as plt
import numpy as np
#import scipy
from scipy import misc
# %matplotlib inline

# %%
#####################
# Training data     # X & Y
#####################

# %%
#DATA_ROOT = "/Users/cesare.chung/int/01_CODE_UNET/NEW2/"
DATA_ROOT = "D:/Cesare/tf_UNET_int/NEW350/"
#
# Training
#
masks_dir = sorted(glob.glob(DATA_ROOT+"/trainData_tftf/resize2/*_manual1_resized_mask.gif"))
imgs_dir  = sorted(glob.glob(DATA_ROOT+"/trainData_tftf/resize2/*_training_resized_training.tif"))

# Import data
print('Loading training dataset...\n')

X_data=[]
for index,entry in enumerate(imgs_dir):
    img = misc.imread(entry)
    X_data.append(img)

Y_data=[]
for index,entry in enumerate(masks_dir):
    img = misc.imread(entry)
    Y_data.append(img)

#
X_data=np.array(X_data)
Y_data=np.array(Y_data)
#
plt.imshow(X_data[19,...,2], aspect="auto")   # X_data[i,...,j]. i = 1,..., number of samples; j = 1,2,3
plt.title("Image")
plt.show()
plt.imshow(Y_data[19,..., ], aspect="auto",cmap='gray')
plt.title("Ground Truth")
plt.show()
# Out:
# Loading training dataset...

# %%
#####################
# Standardization   # X
#####################

# %%
from sklearn.preprocessing import StandardScaler

stdsc = StandardScaler()

X_data_std=[]
for i in range(0,20):
    img_std = stdsc.fit_transform(X_data[i,...,0])
    X_data_std.append(img_std)

#
X_data_std=np.array(X_data_std)
#
# Out:
# C:\Anaconda3_64\lib\site-packages\sklearn\utils\validation.py:429: DataConversionWarning: Data with input dtype uint8 was converted to float64 by StandardScaler.
#   warnings.warn(msg, _DataConversionWarning)

# %%
print("TRAIN data  shape (Scaled):", X_data_std.shape)

print("TRAIN data  shape:", X_data.shape)
print("TRAIN label shape:", Y_data.shape)
# Out:
# TRAIN data  shape (Scaled): (20, 350, 350)
# TRAIN data  shape: (20, 350, 350, 3)
# TRAIN label shape: (20, 350, 350)

# %%
#####################
# Testing  data     # X & Y
#####################

# %%
#
masks_Testing = sorted(glob.glob(DATA_ROOT+"/testData_tftf/resize2/*_manual1_resized_mask.gif"))
imgs_Testing  = sorted(glob.glob(DATA_ROOT+"/testData_tftf/resize2/*_test_resized_testing.tif"))

# Import data
print('Loading testing dataset...\n')

X_test=[]
for index,entry in enumerate(imgs_Testing):
    img = misc.imread(entry)
    X_test.append(img)

Y_test=[]
for index,entry in enumerate(masks_Testing):
    img = misc.imread(entry)
    Y_test.append(img)

#
X_test=np.array(X_test)
Y_test=np.array(Y_test)
#
plt.imshow(X_test[19,...,2], aspect="auto")   
plt.show()
plt.imshow(Y_test[19,..., ], aspect="auto",cmap='gray')
plt.show()
# Out:
# Loading testing dataset...

# %%
#####################
# Standardization   # X
#####################

# %%
from sklearn.preprocessing import StandardScaler

stdsc = StandardScaler()

X_test_std=[]
for i in range(0,20):
    img_std = stdsc.fit_transform(X_test[i,...,0])
    X_test_std.append(img_std)

#
X_test_std=np.array(X_test_std)
#
# Out:
# C:\Anaconda3_64\lib\site-packages\sklearn\utils\validation.py:429: DataConversionWarning: Data with input dtype uint8 was converted to float64 by StandardScaler.
#   warnings.warn(msg, _DataConversionWarning)

# %%
print("TEST data  shape (Scaled):", X_test_std.shape)

print("TEST  data  shape:", X_test.shape)
print("TEST  label shape:", Y_test.shape)
# Out:
# TEST data  shape (Scaled): (20, 350, 350)
# TEST  data  shape: (20, 350, 350, 3)
# TEST  label shape: (20, 350, 350)

# %%
#print(X_test[14])

# %%
X_data = X_data.astype(np.float32)
Y_data = Y_data.astype(np.bool)

X_test = X_test.astype(np.float32)
Y_test = Y_test.astype(np.bool)

# %%
X_data_std = X_data_std.astype(np.float32)

X_test_std = X_test_std.astype(np.float32)

# %%
#######################
# Training parameters #
#######################
training_iters = 32
epochs = 500
dropout = 0.75
display_step = 10

# %%
#data_provider = image_util.SimpleDataProvider(X_data_std, Y_data, channels=3, n_class=2)
data_provider = image_util.SimpleDataProvider(X_data, Y_data, channels=3, n_class=2)

# %%
print(data_provider.channels)
print(data_provider.n_class)
# Out:
# 3
# 2

# %%
net = unet.Unet(channels=data_provider.channels, n_class=data_provider.n_class, layers=3, features_root=64)
trainer = unet.Trainer(net, optimizer="adam")
# Out:
# 2017-11-27 15:45:46,945 Layers 3, features 64, filter size 3x3, pool size: 2x2

# %%
path = trainer.train(data_provider, "./out", training_iters=training_iters, epochs=epochs, dropout=dropout, display_step=display_step)
# Out:
# 2017-11-27 15:45:58,691 Removing 'D:\Cesare\tf_UNET_int\prediction'
# 2017-11-27 15:45:58,692 Removing 'D:\Cesare\tf_UNET_int\out'
# 2017-11-27 15:45:58,693 Allocating 'D:\Cesare\tf_UNET_int\prediction'
# 2017-11-27 15:45:58,694 Allocating 'D:\Cesare\tf_UNET_int\out'
# 2017-11-27 15:46:34,057 Verification error= 49.8%, loss= 0.6932
# 2017-11-27 15:46:41,192 Start optimization
# 2017-11-27 15:46:56,722 Iter 0, Minibatch Loss= 0.6101, Training Accuracy= 0.7471, Minibatch error= 25.3%
# 2017-11-27 15:47:17,247 Iter 10, Minibatch Loss= 0.5940, Training Accuracy= 0.7949, Minibatch error= 20.5%
# 2017-11-27 15:47:37,569 Iter 20, Minibatch Loss= 0.5698, Training Accuracy= 0.7400, Minibatch error= 26.0%
# 2017-11-27 15:47:56,348 Iter 30, Minibatch Loss= 0.5556, Training Accuracy= 0.7471, Minibatch error= 25.3%
# 2017-11-27 15:47:58,198 Epoch 0, Average loss: 0.6168, learning rate: 0.0010
# 2017-11-27 15:47:59,828 Verification error= 25.4%, loss= 0.5542
# 2017-11-27 15:48:23,340 Iter 40, Minibatch Loss= 0.5157, Training Accuracy= 0.8075, Minibatch error= 19.3%
# 2017-11-27 15:48:42,848 Iter 50, Minibatch Loss= 0.5293, Training Accuracy= 0.7949, Minibatch error= 20.5%
# 2017-11-27 15:49:04,488 Iter 60, Minibatch Loss= 0.5514, Training Accuracy= 0.7201, Minibatch error= 28.0%
# 2017-11-27 15:49:10,236 Epoch 1, Average loss: 0.5527, learning rate: 0.0010
# 2017-11-27 15:49:11,836 Verification error= 25.4%, loss= 0.5424
# 2017-11-27 15:49:34,188 Iter 70, Minibatch Loss= 0.5729, Training Accuracy= 0.6697, Minibatch error= 33.0%
# 2017-11-27 15:49:53,957 Iter 80, Minibatch Loss= 0.5577, Training Accuracy= 0.6992, Minibatch error= 30.1%
# 2017-11-27 15:50:14,211 Iter 90, Minibatch Loss= 0.5492, Training Accuracy= 0.7201, Minibatch error= 28.0%
# 2017-11-27 15:50:24,850 Epoch 2, Average loss: 0.5358, learning rate: 0.0010
# 2017-11-27 15:50:26,762 Verification error= 25.4%, loss= 0.5449
# 2017-11-27 15:50:43,919 Iter 100, Minibatch Loss= 0.5604, Training Accuracy= 0.7078, Minibatch error= 29.2%
# 2017-11-27 15:51:04,938 Iter 110, Minibatch Loss= 0.5507, Training Accuracy= 0.7284, Minibatch error= 27.2%
# 2017-11-27 15:51:26,217 Iter 120, Minibatch Loss= 0.5452, Training Accuracy= 0.7248, Minibatch error= 27.5%
# 2017-11-27 15:51:40,061 Epoch 3, Average loss: 0.5348, learning rate: 0.0010
# 2017-11-27 15:51:41,735 Verification error= 25.4%, loss= 0.5385
# 2017-11-27 15:51:56,335 Iter 130, Minibatch Loss= 0.5490, Training Accuracy= 0.7284, Minibatch error= 27.2%
# 2017-11-27 15:52:17,642 Iter 140, Minibatch Loss= 0.5436, Training Accuracy= 0.7330, Minibatch error= 26.7%
# 2017-11-27 15:52:38,068 Iter 150, Minibatch Loss= 0.5491, Training Accuracy= 0.7285, Minibatch error= 27.2%
# 2017-11-27 15:52:55,891 Epoch 4, Average loss: 0.5366, learning rate: 0.0010
# 2017-11-27 15:52:57,506 Verification error= 25.4%, loss= 0.5434
# 2017-11-27 15:53:10,253 Iter 160, Minibatch Loss= 0.5259, Training Accuracy= 0.7949, Minibatch error= 20.5%
# 2017-11-27 15:53:31,135 Iter 170, Minibatch Loss= 0.5658, Training Accuracy= 0.6950, Minibatch error= 30.5%
# 2017-11-27 15:53:51,344 Iter 180, Minibatch Loss= 0.5400, Training Accuracy= 0.7513, Minibatch error= 24.9%
# 2017-11-27 15:54:11,951 Iter 190, Minibatch Loss= 0.5636, Training Accuracy= 0.6950, Minibatch error= 30.5%
# 2017-11-27 15:54:13,888 Epoch 5, Average loss: 0.5339, learning rate: 0.0010
# 2017-11-27 15:54:15,340 Verification error= 25.4%, loss= 0.5395
# 2017-11-27 15:54:43,750 Iter 200, Minibatch Loss= 0.5655, Training Accuracy= 0.6950, Minibatch error= 30.5%
# 2017-11-27 15:55:04,507 Iter 210, Minibatch Loss= 0.5457, Training Accuracy= 0.7320, Minibatch error= 26.8%
# 2017-11-27 15:55:25,302 Iter 220, Minibatch Loss= 0.5657, Training Accuracy= 0.6950, Minibatch error= 30.5%
# 2017-11-27 15:55:31,270 Epoch 6, Average loss: 0.5384, learning rate: 0.0010
# 2017-11-27 15:55:32,955 Verification error= 25.4%, loss= 0.5435
# 2017-11-27 15:55:56,900 Iter 230, Minibatch Loss= 0.5537, Training Accuracy= 0.7201, Minibatch error= 28.0%
# 2017-11-27 15:56:17,990 Iter 240, Minibatch Loss= 0.5499, Training Accuracy= 0.7217, Minibatch error= 27.8%
# 2017-11-27 15:56:37,967 Iter 250, Minibatch Loss= 0.5637, Training Accuracy= 0.7108, Minibatch error= 28.9%
# 2017-11-27 15:56:47,729 Epoch 7, Average loss: 0.5404, learning rate: 0.0010
# 2017-11-27 15:56:49,158 Verification error= 25.4%, loss= 0.5491
# 2017-11-27 15:57:08,762 Iter 260, Minibatch Loss= 0.5197, Training Accuracy= 0.8075, Minibatch error= 19.3%
# 2017-11-27 15:57:29,215 Iter 270, Minibatch Loss= 0.5727, Training Accuracy= 0.6697, Minibatch error= 33.0%
# 2017-11-27 15:57:49,886 Iter 280, Minibatch Loss= 0.5322, Training Accuracy= 0.7949, Minibatch error= 20.5%
# 2017-11-27 15:58:02,842 Epoch 8, Average loss: 0.5406, learning rate: 0.0010
# 2017-11-27 15:58:04,467 Verification error= 25.4%, loss= 0.5414
# 2017-11-27 15:58:21,047 Iter 290, Minibatch Loss= 0.5434, Training Accuracy= 0.7471, Minibatch error= 25.3%
# 2017-11-27 15:58:40,902 Iter 300, Minibatch Loss= 0.5570, Training Accuracy= 0.7078, Minibatch error= 29.2%
# 2017-11-27 15:59:00,995 Iter 310, Minibatch Loss= 0.5256, Training Accuracy= 0.7949, Minibatch error= 20.5%
# 2017-11-27 15:59:17,678 Epoch 9, Average loss: 0.5370, learning rate: 0.0010
# 2017-11-27 15:59:19,203 Verification error= 25.4%, loss= 0.5379
# 2017-11-27 15:59:31,412 Iter 320, Minibatch Loss= 0.5408, Training Accuracy= 0.7471, Minibatch error= 25.3%
# 2017-11-27 15:59:51,910 Iter 330, Minibatch Loss= 0.5412, Training Accuracy= 0.7471, Minibatch error= 25.3%
# 2017-11-27 16:00:12,137 Iter 340, Minibatch Loss= 0.5508, Training Accuracy= 0.7284, Minibatch error= 27.2%
# 2017-11-27 16:00:32,370 Iter 350, Minibatch Loss= 0.5479, Training Accuracy= 0.7284, Minibatch error= 27.2%
# 2017-11-27 16:00:34,482 Epoch 10, Average loss: 0.5398, learning rate: 0.0010
# 2017-11-27 16:00:36,132 Verification error= 25.4%, loss= 0.5394
# 2017-11-27 16:01:05,219 Iter 360, Minibatch Loss= 0.5395, Training Accuracy= 0.7400, Minibatch error= 26.0%
# 2017-11-27 16:01:27,299 Iter 370, Minibatch Loss= 0.5466, Training Accuracy= 0.7248, Minibatch error= 27.5%
# 2017-11-27 16:01:47,907 Iter 380, Minibatch Loss= 0.5508, Training Accuracy= 0.7201, Minibatch error= 28.0%
# 2017-11-27 16:01:53,775 Epoch 11, Average loss: 0.5312, learning rate: 0.0010
# 2017-11-27 16:01:55,502 Verification error= 25.4%, loss= 0.5407
# 2017-11-27 16:02:21,097 Iter 390, Minibatch Loss= 0.5640, Training Accuracy= 0.6950, Minibatch error= 30.5%
# 2017-11-27 16:02:40,970 Iter 400, Minibatch Loss= 0.5589, Training Accuracy= 0.6992, Minibatch error= 30.1%
# 2017-11-27 16:03:01,450 Iter 410, Minibatch Loss= 0.5373, Training Accuracy= 0.7538, Minibatch error= 24.6%
# 2017-11-27 16:03:10,992 Epoch 12, Average loss: 0.5382, learning rate: 0.0010
# 2017-11-27 16:03:12,405 Verification error= 25.4%, loss= 0.5396
# 2017-11-27 16:03:36,573 Iter 420, Minibatch Loss= 0.5135, Training Accuracy= 0.8075, Minibatch error= 19.3%
# 2017-11-27 16:03:57,777 Iter 430, Minibatch Loss= 0.5729, Training Accuracy= 0.6697, Minibatch error= 33.0%
# 2017-11-27 16:04:18,541 Iter 440, Minibatch Loss= 0.5530, Training Accuracy= 0.7217, Minibatch error= 27.8%
# 2017-11-27 16:04:32,120 Epoch 13, Average loss: 0.5360, learning rate: 0.0010
# 2017-11-27 16:04:33,555 Verification error= 25.4%, loss= 0.5396
# 2017-11-27 16:04:55,895 Iter 450, Minibatch Loss= 0.5409, Training Accuracy= 0.7400, Minibatch error= 26.0%
# 2017-11-27 16:05:17,001 Iter 460, Minibatch Loss= 0.5574, Training Accuracy= 0.7078, Minibatch error= 29.2%
# 2017-11-27 16:05:39,056 Iter 470, Minibatch Loss= 0.5407, Training Accuracy= 0.7513, Minibatch error= 24.9%
# 2017-11-27 16:05:56,643 Epoch 14, Average loss: 0.5403, learning rate: 0.0010
# 2017-11-27 16:05:58,523 Verification error= 25.4%, loss= 0.5415
# 2017-11-27 16:06:15,733 Iter 480, Minibatch Loss= 0.5424, Training Accuracy= 0.7471, Minibatch error= 25.3%
# 2017-11-27 16:06:37,306 Iter 490, Minibatch Loss= 0.5334, Training Accuracy= 0.7513, Minibatch error= 24.9%
# 2017-11-27 16:06:58,112 Iter 500, Minibatch Loss= 0.5496, Training Accuracy= 0.7201, Minibatch error= 28.0%
# 2017-11-27 16:07:19,447 Iter 510, Minibatch Loss= 0.5115, Training Accuracy= 0.8075, Minibatch error= 19.3%
# 2017-11-27 16:07:21,662 Epoch 15, Average loss: 0.5260, learning rate: 0.0010
# 2017-11-27 16:07:23,505 Verification error= 25.4%, loss= 0.5320
# 2017-11-27 16:07:55,083 Iter 520, Minibatch Loss= 0.5221, Training Accuracy= 0.8075, Minibatch error= 19.3%
# 2017-11-27 16:08:16,693 Iter 530, Minibatch Loss= 0.5537, Training Accuracy= 0.7078, Minibatch error= 29.2%
# 2017-11-27 16:08:37,818 Iter 540, Minibatch Loss= 0.5513, Training Accuracy= 0.7108, Minibatch error= 28.9%
# 2017-11-27 16:08:43,898 Epoch 16, Average loss: 0.5331, learning rate: 0.0010
# 2017-11-27 16:08:45,588 Verification error= 25.4%, loss= 0.5304
# 2017-11-27 16:09:15,967 Iter 550, Minibatch Loss= 0.5332, Training Accuracy= 0.7513, Minibatch error= 24.9%
# 2017-11-27 16:09:36,527 Iter 560, Minibatch Loss= 0.5757, Training Accuracy= 0.6697, Minibatch error= 33.0%
# 2017-11-27 16:09:58,525 Iter 570, Minibatch Loss= 0.5426, Training Accuracy= 0.7284, Minibatch error= 27.2%
# 2017-11-27 16:10:08,274 Epoch 17, Average loss: 0.5399, learning rate: 0.0010
# 2017-11-27 16:10:09,973 Verification error= 25.4%, loss= 0.5351
# 2017-11-27 16:10:33,593 Iter 580, Minibatch Loss= 0.5776, Training Accuracy= 0.6526, Minibatch error= 34.7%
# 2017-11-27 16:10:55,486 Iter 590, Minibatch Loss= 0.5082, Training Accuracy= 0.8075, Minibatch error= 19.3%
# 2017-11-27 16:11:17,354 Iter 600, Minibatch Loss= 0.5372, Training Accuracy= 0.7471, Minibatch error= 25.3%
# 2017-11-27 16:11:31,091 Epoch 18, Average loss: 0.5389, learning rate: 0.0010
# 2017-11-27 16:11:32,845 Verification error= 25.4%, loss= 0.5208
# 2017-11-27 16:11:54,714 Iter 610, Minibatch Loss= 0.5448, Training Accuracy= 0.7217, Minibatch error= 27.8%
# 2017-11-27 16:12:16,448 Iter 620, Minibatch Loss= 0.5137, Training Accuracy= 0.8075, Minibatch error= 19.3%
# 2017-11-27 16:12:38,175 Iter 630, Minibatch Loss= 0.5352, Training Accuracy= 0.7513, Minibatch error= 24.9%
# 2017-11-27 16:12:55,891 Epoch 19, Average loss: 0.5457, learning rate: 0.0010
# 2017-11-27 16:12:57,899 Verification error= 25.4%, loss= 0.5392
# 2017-11-27 16:13:16,649 Iter 640, Minibatch Loss= 0.5185, Training Accuracy= 0.7949, Minibatch error= 20.5%
# 2017-11-27 16:13:38,228 Iter 650, Minibatch Loss= 0.5737, Training Accuracy= 0.6697, Minibatch error= 33.0%
# 2017-11-27 16:14:00,657 Iter 660, Minibatch Loss= 0.5557, Training Accuracy= 0.7108, Minibatch error= 28.9%
# 2017-11-27 16:14:24,202 Iter 670, Minibatch Loss= 0.5740, Training Accuracy= 0.6526, Minibatch error= 34.7%
# 2017-11-27 16:14:26,447 Epoch 20, Average loss: 0.5413, learning rate: 0.0010
# 2017-11-27 16:14:28,091 Verification error= 25.4%, loss= 0.5329
# 2017-11-27 16:15:05,234 Iter 680, Minibatch Loss= 0.5296, Training Accuracy= 0.7330, Minibatch error= 26.7%
# 2017-11-27 16:15:26,090 Iter 690, Minibatch Loss= 0.5366, Training Accuracy= 0.7471, Minibatch error= 25.3%
# 2017-11-27 16:15:49,127 Iter 700, Minibatch Loss= 0.4994, Training Accuracy= 0.8075, Minibatch error= 19.3%
# 2017-11-27 16:15:55,151 Epoch 21, Average loss: 0.5363, learning rate: 0.0010
# 2017-11-27 16:15:56,994 Verification error= 25.4%, loss= 0.5297
# 2017-11-27 16:16:30,089 Iter 710, Minibatch Loss= 0.5417, Training Accuracy= 0.7330, Minibatch error= 26.7%
# 2017-11-27 16:16:52,505 Iter 720, Minibatch Loss= 0.5391, Training Accuracy= 0.7320, Minibatch error= 26.8%
# 2017-11-27 16:17:14,731 Iter 730, Minibatch Loss= 0.5501, Training Accuracy= 0.7217, Minibatch error= 27.8%
# 2017-11-27 16:17:24,638 Epoch 22, Average loss: 0.5393, learning rate: 0.0010
# 2017-11-27 16:17:26,172 Verification error= 25.4%, loss= 0.5382
# 2017-11-27 16:17:55,643 Iter 740, Minibatch Loss= 0.5749, Training Accuracy= 0.6697, Minibatch error= 33.0%
# 2017-11-27 16:18:17,303 Iter 750, Minibatch Loss= 0.5438, Training Accuracy= 0.7248, Minibatch error= 27.5%
# 2017-11-27 16:18:39,059 Iter 760, Minibatch Loss= 0.5570, Training Accuracy= 0.6992, Minibatch error= 30.1%
# 2017-11-27 16:18:53,196 Epoch 23, Average loss: 0.5469, learning rate: 0.0010
# 2017-11-27 16:18:54,775 Verification error= 25.4%, loss= 0.5392
# 2017-11-27 16:19:20,992 Iter 770, Minibatch Loss= 0.5489, Training Accuracy= 0.7096, Minibatch error= 29.0%
# 2017-11-27 16:19:42,702 Iter 780, Minibatch Loss= 0.5484, Training Accuracy= 0.7096, Minibatch error= 29.0%
# 2017-11-27 16:20:05,147 Iter 790, Minibatch Loss= 0.5374, Training Accuracy= 0.7471, Minibatch error= 25.3%
# 2017-11-27 16:20:23,691 Epoch 24, Average loss: 0.5358, learning rate: 0.0010
# 2017-11-27 16:20:25,357 Verification error= 25.4%, loss= 0.5357
# 2017-11-27 16:20:48,539 Iter 800, Minibatch Loss= 0.5385, Training Accuracy= 0.7330, Minibatch error= 26.7%
# 2017-11-27 16:21:11,820 Iter 810, Minibatch Loss= 0.5434, Training Accuracy= 0.7330, Minibatch error= 26.7%
# 2017-11-27 16:21:34,090 Iter 820, Minibatch Loss= 0.5271, Training Accuracy= 0.7538, Minibatch error= 24.6%
# 2017-11-27 16:21:56,356 Iter 830, Minibatch Loss= 0.5284, Training Accuracy= 0.7538, Minibatch error= 24.6%
# 2017-11-27 16:21:58,784 Epoch 25, Average loss: 0.5379, learning rate: 0.0010
# 2017-11-27 16:22:00,489 Verification error= 25.4%, loss= 0.5324
# 2017-11-27 16:22:39,592 Iter 840, Minibatch Loss= 0.5431, Training Accuracy= 0.7284, Minibatch error= 27.2%
# 2017-11-27 16:23:00,616 Iter 850, Minibatch Loss= 0.5616, Training Accuracy= 0.6950, Minibatch error= 30.5%
# 2017-11-27 16:23:21,855 Iter 860, Minibatch Loss= 0.5413, Training Accuracy= 0.7285, Minibatch error= 27.2%
# 2017-11-27 16:23:27,861 Epoch 26, Average loss: 0.5361, learning rate: 0.0010
# 2017-11-27 16:23:29,723 Verification error= 25.4%, loss= 0.5307
# 2017-11-27 16:24:02,710 Iter 870, Minibatch Loss= 0.5500, Training Accuracy= 0.7108, Minibatch error= 28.9%
# 2017-11-27 16:24:24,536 Iter 880, Minibatch Loss= 0.5399, Training Accuracy= 0.7320, Minibatch error= 26.8%
# 2017-11-27 16:24:45,606 Iter 890, Minibatch Loss= 0.5723, Training Accuracy= 0.6697, Minibatch error= 33.0%
# 2017-11-27 16:24:55,917 Epoch 27, Average loss: 0.5396, learning rate: 0.0010
# 2017-11-27 16:24:57,333 Verification error= 25.4%, loss= 0.5411
# 2017-11-27 16:25:27,530 Iter 900, Minibatch Loss= 0.5561, Training Accuracy= 0.6992, Minibatch error= 30.1%
# 2017-11-27 16:25:48,630 Iter 910, Minibatch Loss= 0.5052, Training Accuracy= 0.8075, Minibatch error= 19.3%
# 2017-11-27 16:26:09,922 Iter 920, Minibatch Loss= 0.5482, Training Accuracy= 0.7096, Minibatch error= 29.0%
# 2017-11-27 16:26:23,891 Epoch 28, Average loss: 0.5400, learning rate: 0.0010
# 2017-11-27 16:26:25,367 Verification error= 25.4%, loss= 0.5418
# 2017-11-27 16:26:53,003 Iter 930, Minibatch Loss= 0.5530, Training Accuracy= 0.7201, Minibatch error= 28.0%
# 2017-11-27 16:27:15,459 Iter 940, Minibatch Loss= 0.5230, Training Accuracy= 0.7400, Minibatch error= 26.0%
# 2017-11-27 16:27:39,087 Iter 950, Minibatch Loss= 0.5778, Training Accuracy= 0.6526, Minibatch error= 34.7%
# 2017-11-27 16:27:58,540 Epoch 29, Average loss: 0.5410, learning rate: 0.0010
# 2017-11-27 16:28:00,422 Verification error= 25.4%, loss= 0.5333
# 2017-11-27 16:28:24,383 Iter 960, Minibatch Loss= 0.5470, Training Accuracy= 0.7217, Minibatch error= 27.8%
# 2017-11-27 16:28:46,400 Iter 970, Minibatch Loss= 0.5062, Training Accuracy= 0.7949, Minibatch error= 20.5%
# 2017-11-27 16:29:07,099 Iter 980, Minibatch Loss= 0.5340, Training Accuracy= 0.7538, Minibatch error= 24.6%
# 2017-11-27 16:29:27,838 Iter 990, Minibatch Loss= 0.5443, Training Accuracy= 0.7284, Minibatch error= 27.2%
# 2017-11-27 16:29:30,141 Epoch 30, Average loss: 0.5368, learning rate: 0.0010
# 2017-11-27 16:29:31,776 Verification error= 25.4%, loss= 0.5337
# 2017-11-27 16:30:11,799 Iter 1000, Minibatch Loss= 0.5271, Training Accuracy= 0.7513, Minibatch error= 24.9%
# 2017-11-27 16:30:34,598 Iter 1010, Minibatch Loss= 0.5188, Training Accuracy= 0.7949, Minibatch error= 20.5%
# 2017-11-27 16:30:56,008 Iter 1020, Minibatch Loss= 0.5386, Training Accuracy= 0.7285, Minibatch error= 27.2%
# 2017-11-27 16:31:02,073 Epoch 31, Average loss: 0.5379, learning rate: 0.0010
# 2017-11-27 16:31:03,769 Verification error= 25.4%, loss= 0.5298
# 2017-11-27 16:31:40,842 Iter 1030, Minibatch Loss= 0.5597, Training Accuracy= 0.6950, Minibatch error= 30.5%
# 2017-11-27 16:32:01,511 Iter 1040, Minibatch Loss= 0.5244, Training Accuracy= 0.7513, Minibatch error= 24.9%
# 2017-11-27 16:32:23,303 Iter 1050, Minibatch Loss= 0.5363, Training Accuracy= 0.7513, Minibatch error= 24.9%
# 2017-11-27 16:32:33,702 Epoch 32, Average loss: 0.5360, learning rate: 0.0010
# 2017-11-27 16:32:35,355 Verification error= 25.4%, loss= 0.5414
# 2017-11-27 16:33:08,878 Iter 1060, Minibatch Loss= 0.5533, Training Accuracy= 0.7108, Minibatch error= 28.9%
# 2017-11-27 16:33:33,535 Iter 1070, Minibatch Loss= 0.5335, Training Accuracy= 0.7330, Minibatch error= 26.7%
# 2017-11-27 16:33:57,158 Iter 1080, Minibatch Loss= 0.5745, Training Accuracy= 0.6526, Minibatch error= 34.7%
# 2017-11-27 16:34:12,980 Epoch 33, Average loss: 0.5406, learning rate: 0.0010
# 2017-11-27 16:34:14,734 Verification error= 25.4%, loss= 0.5276
# 2017-11-27 16:34:44,982 Iter 1090, Minibatch Loss= 0.5336, Training Accuracy= 0.7284, Minibatch error= 27.2%
# 2017-11-27 16:35:07,657 Iter 1100, Minibatch Loss= 0.5524, Training Accuracy= 0.7201, Minibatch error= 28.0%
# 2017-11-27 16:35:30,726 Iter 1110, Minibatch Loss= 0.5535, Training Accuracy= 0.6992, Minibatch error= 30.1%
# 2017-11-27 16:35:50,404 Epoch 34, Average loss: 0.5358, learning rate: 0.0010
# 2017-11-27 16:35:51,924 Verification error= 25.4%, loss= 0.5315
# 2017-11-27 16:36:18,700 Iter 1120, Minibatch Loss= 0.5040, Training Accuracy= 0.8075, Minibatch error= 19.3%
# 2017-11-27 16:36:41,004 Iter 1130, Minibatch Loss= 0.5383, Training Accuracy= 0.7284, Minibatch error= 27.2%
# 2017-11-27 16:37:04,211 Iter 1140, Minibatch Loss= 0.5720, Training Accuracy= 0.6697, Minibatch error= 33.0%
# 2017-11-27 16:37:28,191 Iter 1150, Minibatch Loss= 0.5480, Training Accuracy= 0.7108, Minibatch error= 28.9%
# 2017-11-27 16:37:30,453 Epoch 35, Average loss: 0.5320, learning rate: 0.0010
# 2017-11-27 16:37:32,060 Verification error= 25.4%, loss= 0.5233
# 2017-11-27 16:38:14,429 Iter 1160, Minibatch Loss= 0.5304, Training Accuracy= 0.7471, Minibatch error= 25.3%
# 2017-11-27 16:38:37,785 Iter 1170, Minibatch Loss= 0.5452, Training Accuracy= 0.7217, Minibatch error= 27.8%
# 2017-11-27 16:38:59,948 Iter 1180, Minibatch Loss= 0.5449, Training Accuracy= 0.7096, Minibatch error= 29.0%
# 2017-11-27 16:39:06,423 Epoch 36, Average loss: 0.5423, learning rate: 0.0010
# 2017-11-27 16:39:08,055 Verification error= 25.4%, loss= 0.5347
# 2017-11-27 16:39:47,413 Iter 1190, Minibatch Loss= 0.5448, Training Accuracy= 0.7320, Minibatch error= 26.8%
# 2017-11-27 16:40:08,445 Iter 1200, Minibatch Loss= 0.5727, Training Accuracy= 0.6526, Minibatch error= 34.7%
# 2017-11-27 16:40:30,479 Iter 1210, Minibatch Loss= 0.5078, Training Accuracy= 0.7949, Minibatch error= 20.5%
# 2017-11-27 16:40:40,167 Epoch 37, Average loss: 0.5377, learning rate: 0.0010
# 2017-11-27 16:40:41,656 Verification error= 25.4%, loss= 0.5333
# 2017-11-27 16:41:16,647 Iter 1220, Minibatch Loss= 0.5644, Training Accuracy= 0.6950, Minibatch error= 30.5%
# 2017-11-27 16:41:37,976 Iter 1230, Minibatch Loss= 0.5736, Training Accuracy= 0.6697, Minibatch error= 33.0%
# 2017-11-27 16:41:59,964 Iter 1240, Minibatch Loss= 0.5314, Training Accuracy= 0.7330, Minibatch error= 26.7%
# 2017-11-27 16:42:14,070 Epoch 38, Average loss: 0.5324, learning rate: 0.0010
# 2017-11-27 16:42:15,576 Verification error= 25.4%, loss= 0.5279
# 2017-11-27 16:42:47,138 Iter 1250, Minibatch Loss= 0.5379, Training Accuracy= 0.7284, Minibatch error= 27.2%
# 2017-11-27 16:43:11,777 Iter 1260, Minibatch Loss= 0.5243, Training Accuracy= 0.7320, Minibatch error= 26.8%
# 2017-11-27 16:43:36,026 Iter 1270, Minibatch Loss= 0.5488, Training Accuracy= 0.6992, Minibatch error= 30.1%
# 2017-11-27 16:43:56,976 Epoch 39, Average loss: 0.5279, learning rate: 0.0010
# 2017-11-27 16:43:58,685 Verification error= 26.5%, loss= 0.5279
# 2017-11-27 16:44:25,425 Iter 1280, Minibatch Loss= 0.5272, Training Accuracy= 0.7267, Minibatch error= 27.3%
# 2017-11-27 16:44:48,206 Iter 1290, Minibatch Loss= 0.5029, Training Accuracy= 0.7817, Minibatch error= 21.8%
# 2017-11-27 16:45:09,143 Iter 1300, Minibatch Loss= 0.5539, Training Accuracy= 0.7182, Minibatch error= 28.2%
# 2017-11-27 16:45:30,713 Iter 1310, Minibatch Loss= 0.5514, Training Accuracy= 0.6877, Minibatch error= 31.2%
# 2017-11-27 16:45:33,005 Epoch 40, Average loss: 0.5250, learning rate: 0.0010
# 2017-11-27 16:45:34,543 Verification error= 28.1%, loss= 0.5202
# 2017-11-27 16:46:19,847 Iter 1320, Minibatch Loss= 0.5446, Training Accuracy= 0.7201, Minibatch error= 28.0%
# 2017-11-27 16:46:43,121 Iter 1330, Minibatch Loss= 0.5247, Training Accuracy= 0.7536, Minibatch error= 24.6%
# 2017-11-27 16:47:03,963 Iter 1340, Minibatch Loss= 0.5413, Training Accuracy= 0.7101, Minibatch error= 29.0%
# 2017-11-27 16:47:10,337 Epoch 41, Average loss: 0.5242, learning rate: 0.0010
# 2017-11-27 16:47:11,856 Verification error= 25.4%, loss= 0.5289
# 2017-11-27 16:47:54,200 Iter 1350, Minibatch Loss= 0.5186, Training Accuracy= 0.7824, Minibatch error= 21.8%
# 2017-11-27 16:48:17,917 Iter 1360, Minibatch Loss= 0.4912, Training Accuracy= 0.7888, Minibatch error= 21.1%
# 2017-11-27 16:48:41,698 Iter 1370, Minibatch Loss= 0.5268, Training Accuracy= 0.7247, Minibatch error= 27.5%
# 2017-11-27 16:48:53,093 Epoch 42, Average loss: 0.5107, learning rate: 0.0010
# 2017-11-27 16:48:54,867 Verification error= 22.9%, loss= 0.5042
# 2017-11-27 16:49:32,900 Iter 1380, Minibatch Loss= 0.5313, Training Accuracy= 0.7035, Minibatch error= 29.6%
# 2017-11-27 16:49:57,035 Iter 1390, Minibatch Loss= 0.5192, Training Accuracy= 0.7547, Minibatch error= 24.5%
# 2017-11-27 16:50:20,423 Iter 1400, Minibatch Loss= 0.5259, Training Accuracy= 0.7251, Minibatch error= 27.5%
# 2017-11-27 16:50:36,908 Epoch 43, Average loss: 0.5063, learning rate: 0.0010
# 2017-11-27 16:50:38,750 Verification error= 21.8%, loss= 0.4936
# 2017-11-27 16:51:10,328 Iter 1410, Minibatch Loss= 0.4944, Training Accuracy= 0.7823, Minibatch error= 21.8%
# 2017-11-27 16:51:32,984 Iter 1420, Minibatch Loss= 0.4983, Training Accuracy= 0.7577, Minibatch error= 24.2%
# 2017-11-27 16:51:54,947 Iter 1430, Minibatch Loss= 0.5442, Training Accuracy= 0.6978, Minibatch error= 30.2%
# 2017-11-27 16:52:13,360 Epoch 44, Average loss: 0.4928, learning rate: 0.0010
# 2017-11-27 16:52:14,822 Verification error= 23.7%, loss= 0.5417
# 2017-11-27 16:52:41,170 Iter 1440, Minibatch Loss= 0.5610, Training Accuracy= 0.6645, Minibatch error= 33.6%
# 2017-11-27 16:53:04,138 Iter 1450, Minibatch Loss= 0.4968, Training Accuracy= 0.7662, Minibatch error= 23.4%
# 2017-11-27 16:53:26,478 Iter 1460, Minibatch Loss= 0.5183, Training Accuracy= 0.7396, Minibatch error= 26.0%
# 2017-11-27 16:53:48,679 Iter 1470, Minibatch Loss= 0.4506, Training Accuracy= 0.8153, Minibatch error= 18.5%
# 2017-11-27 16:53:50,974 Epoch 45, Average loss: 0.4911, learning rate: 0.0010
# 2017-11-27 16:53:52,665 Verification error= 21.2%, loss= 0.4781
# 2017-11-27 16:54:39,185 Iter 1480, Minibatch Loss= 0.4793, Training Accuracy= 0.7908, Minibatch error= 20.9%
# 2017-11-27 16:55:04,578 Iter 1490, Minibatch Loss= 0.4610, Training Accuracy= 0.7862, Minibatch error= 21.4%
# 2017-11-27 16:55:27,587 Iter 1500, Minibatch Loss= 0.4426, Training Accuracy= 0.8016, Minibatch error= 19.8%
# 2017-11-27 16:55:34,854 Epoch 46, Average loss: 0.4696, learning rate: 0.0010
# 2017-11-27 16:55:36,744 Verification error= 22.0%, loss= 0.4911
# 2017-11-27 16:56:18,299 Iter 1510, Minibatch Loss= 0.5015, Training Accuracy= 0.7432, Minibatch error= 25.7%
# 2017-11-27 16:56:42,255 Iter 1520, Minibatch Loss= 0.5259, Training Accuracy= 0.7680, Minibatch error= 23.2%
# 2017-11-27 16:57:07,290 Iter 1530, Minibatch Loss= 0.4661, Training Accuracy= 0.7823, Minibatch error= 21.8%
# 2017-11-27 16:57:18,473 Epoch 47, Average loss: 0.4760, learning rate: 0.0010
# 2017-11-27 16:57:20,052 Verification error= 19.9%, loss= 0.4580
# 2017-11-27 16:57:56,544 Iter 1540, Minibatch Loss= 0.4674, Training Accuracy= 0.7808, Minibatch error= 21.9%
# 2017-11-27 16:58:18,381 Iter 1550, Minibatch Loss= 0.4707, Training Accuracy= 0.7943, Minibatch error= 20.6%
# 2017-11-27 16:58:39,333 Iter 1560, Minibatch Loss= 0.4950, Training Accuracy= 0.7671, Minibatch error= 23.3%
# 2017-11-27 16:58:52,978 Epoch 48, Average loss: 0.4498, learning rate: 0.0010
# 2017-11-27 16:58:54,613 Verification error= 20.2%, loss= 0.4645
# 2017-11-27 16:59:27,436 Iter 1570, Minibatch Loss= 0.4375, Training Accuracy= 0.8174, Minibatch error= 18.3%
# 2017-11-27 16:59:52,487 Iter 1580, Minibatch Loss= 0.4112, Training Accuracy= 0.8217, Minibatch error= 17.8%
# 2017-11-27 17:00:15,477 Iter 1590, Minibatch Loss= 0.4406, Training Accuracy= 0.8135, Minibatch error= 18.6%
# 2017-11-27 17:00:35,591 Epoch 49, Average loss: 0.4294, learning rate: 0.0010
# 2017-11-27 17:00:37,230 Verification error= 19.2%, loss= 0.4218
# 2017-11-27 17:01:06,895 Iter 1600, Minibatch Loss= 0.3951, Training Accuracy= 0.8319, Minibatch error= 16.8%
# 2017-11-27 17:01:29,807 Iter 1610, Minibatch Loss= 0.5077, Training Accuracy= 0.7135, Minibatch error= 28.7%
# 2017-11-27 17:01:52,779 Iter 1620, Minibatch Loss= 0.3772, Training Accuracy= 0.8360, Minibatch error= 16.4%
# 2017-11-27 17:02:15,763 Iter 1630, Minibatch Loss= 0.4026, Training Accuracy= 0.8334, Minibatch error= 16.7%
# 2017-11-27 17:02:18,225 Epoch 50, Average loss: 0.4154, learning rate: 0.0010
# 2017-11-27 17:02:19,829 Verification error= 19.0%, loss= 0.4260
# 2017-11-27 17:03:04,844 Iter 1640, Minibatch Loss= 0.4284, Training Accuracy= 0.8040, Minibatch error= 19.6%
# 2017-11-27 17:03:27,978 Iter 1650, Minibatch Loss= 0.4365, Training Accuracy= 0.8108, Minibatch error= 18.9%
# 2017-11-27 17:03:49,694 Iter 1660, Minibatch Loss= 0.4530, Training Accuracy= 0.7792, Minibatch error= 22.1%
# 2017-11-27 17:03:55,926 Epoch 51, Average loss: 0.4073, learning rate: 0.0010
# 2017-11-27 17:03:57,718 Verification error= 23.6%, loss= 0.4786
# 2017-11-27 17:04:40,732 Iter 1670, Minibatch Loss= 0.4851, Training Accuracy= 0.7461, Minibatch error= 25.4%
# 2017-11-27 17:05:05,497 Iter 1680, Minibatch Loss= 0.4405, Training Accuracy= 0.7803, Minibatch error= 22.0%
# 2017-11-27 17:05:28,692 Iter 1690, Minibatch Loss= 0.4026, Training Accuracy= 0.8065, Minibatch error= 19.4%
# 2017-11-27 17:05:38,979 Epoch 52, Average loss: 0.3996, learning rate: 0.0010
# 2017-11-27 17:05:40,809 Verification error= 19.8%, loss= 0.4129
# 2017-11-27 17:06:18,943 Iter 1700, Minibatch Loss= 0.4325, Training Accuracy= 0.7914, Minibatch error= 20.9%
# 2017-11-27 17:06:42,201 Iter 1710, Minibatch Loss= 0.4358, Training Accuracy= 0.7850, Minibatch error= 21.5%
# 2017-11-27 17:07:05,164 Iter 1720, Minibatch Loss= 0.5106, Training Accuracy= 0.7168, Minibatch error= 28.3%
# 2017-11-27 17:07:20,283 Epoch 53, Average loss: 0.3914, learning rate: 0.0010
# 2017-11-27 17:07:22,081 Verification error= 24.2%, loss= 0.4652
# 2017-11-27 17:07:56,246 Iter 1730, Minibatch Loss= 0.5776, Training Accuracy= 0.6566, Minibatch error= 34.3%
# 2017-11-27 17:08:19,252 Iter 1740, Minibatch Loss= 0.5821, Training Accuracy= 0.6758, Minibatch error= 32.4%
# 2017-11-27 17:08:42,758 Iter 1750, Minibatch Loss= 0.4080, Training Accuracy= 0.8058, Minibatch error= 19.4%
# 2017-11-27 17:09:01,801 Epoch 54, Average loss: 0.3893, learning rate: 0.0010
# 2017-11-27 17:09:03,656 Verification error= 21.5%, loss= 0.4275
# 2017-11-27 17:09:33,959 Iter 1760, Minibatch Loss= 0.4972, Training Accuracy= 0.7254, Minibatch error= 27.5%
# 2017-11-27 17:09:56,900 Iter 1770, Minibatch Loss= 0.4555, Training Accuracy= 0.7675, Minibatch error= 23.2%
# 2017-11-27 17:10:18,171 Iter 1780, Minibatch Loss= 0.3885, Training Accuracy= 0.8395, Minibatch error= 16.1%
# 2017-11-27 17:10:40,190 Iter 1790, Minibatch Loss= 0.3951, Training Accuracy= 0.8149, Minibatch error= 18.5%
# 2017-11-27 17:10:42,610 Epoch 55, Average loss: 0.3856, learning rate: 0.0010
# 2017-11-27 17:10:44,202 Verification error= 17.5%, loss= 0.3828
# 2017-11-27 17:11:31,654 Iter 1800, Minibatch Loss= 0.4048, Training Accuracy= 0.8122, Minibatch error= 18.8%
# 2017-11-27 17:11:55,834 Iter 1810, Minibatch Loss= 0.3908, Training Accuracy= 0.8260, Minibatch error= 17.4%
# 2017-11-27 17:12:18,263 Iter 1820, Minibatch Loss= 0.4071, Training Accuracy= 0.8034, Minibatch error= 19.7%
# 2017-11-27 17:12:24,736 Epoch 56, Average loss: 0.3877, learning rate: 0.0010
# 2017-11-27 17:12:26,566 Verification error= 19.3%, loss= 0.3945
# 2017-11-27 17:13:08,821 Iter 1830, Minibatch Loss= 0.4143, Training Accuracy= 0.8141, Minibatch error= 18.6%
# 2017-11-27 17:13:28,890 Iter 1840, Minibatch Loss= 0.3773, Training Accuracy= 0.8455, Minibatch error= 15.5%
# 2017-11-27 17:13:48,355 Iter 1850, Minibatch Loss= 0.4009, Training Accuracy= 0.8009, Minibatch error= 19.9%
# 2017-11-27 17:13:57,581 Epoch 57, Average loss: 0.3744, learning rate: 0.0010
# 2017-11-27 17:13:59,297 Verification error= 23.5%, loss= 0.4380
# 2017-11-27 17:14:35,126 Iter 1860, Minibatch Loss= 0.3917, Training Accuracy= 0.8084, Minibatch error= 19.2%
# 2017-11-27 17:14:56,635 Iter 1870, Minibatch Loss= 0.4260, Training Accuracy= 0.7679, Minibatch error= 23.2%
# 2017-11-27 17:15:18,518 Iter 1880, Minibatch Loss= 0.4178, Training Accuracy= 0.8054, Minibatch error= 19.5%
# 2017-11-27 17:15:33,654 Epoch 58, Average loss: 0.3566, learning rate: 0.0010
# 2017-11-27 17:15:35,321 Verification error= 23.5%, loss= 0.4458
# 2017-11-27 17:16:09,071 Iter 1890, Minibatch Loss= 0.4481, Training Accuracy= 0.7595, Minibatch error= 24.1%
# 2017-11-27 17:16:32,005 Iter 1900, Minibatch Loss= 0.4036, Training Accuracy= 0.8019, Minibatch error= 19.8%
# 2017-11-27 17:16:55,949 Iter 1910, Minibatch Loss= 0.3828, Training Accuracy= 0.8210, Minibatch error= 17.9%
# 2017-11-27 17:17:15,035 Epoch 59, Average loss: 0.3697, learning rate: 0.0010
# 2017-11-27 17:17:16,820 Verification error= 18.7%, loss= 0.3951
# 2017-11-27 17:17:47,863 Iter 1920, Minibatch Loss= 0.4958, Training Accuracy= 0.7105, Minibatch error= 29.0%
# 2017-11-27 17:18:11,826 Iter 1930, Minibatch Loss= 0.3981, Training Accuracy= 0.8168, Minibatch error= 18.3%
# 2017-11-27 17:18:35,003 Iter 1940, Minibatch Loss= 0.3998, Training Accuracy= 0.8013, Minibatch error= 19.9%
# 2017-11-27 17:19:00,336 Iter 1950, Minibatch Loss= 0.4764, Training Accuracy= 0.7242, Minibatch error= 27.6%
# 2017-11-27 17:19:02,731 Epoch 60, Average loss: 0.3566, learning rate: 0.0010
# 2017-11-27 17:19:04,487 Verification error= 30.6%, loss= 0.5083
# 2017-11-27 17:19:51,367 Iter 1960, Minibatch Loss= 0.4111, Training Accuracy= 0.8177, Minibatch error= 18.2%
# 2017-11-27 17:20:12,775 Iter 1970, Minibatch Loss= 0.3563, Training Accuracy= 0.8394, Minibatch error= 16.1%
# 2017-11-27 17:20:32,901 Iter 1980, Minibatch Loss= 0.4042, Training Accuracy= 0.8094, Minibatch error= 19.1%
# 2017-11-27 17:20:38,796 Epoch 61, Average loss: 0.3637, learning rate: 0.0010
# 2017-11-27 17:20:40,658 Verification error= 19.7%, loss= 0.3970
# 2017-11-27 17:21:22,555 Iter 1990, Minibatch Loss= 0.4317, Training Accuracy= 0.7895, Minibatch error= 21.1%
# 2017-11-27 17:21:44,191 Iter 2000, Minibatch Loss= 0.4869, Training Accuracy= 0.7326, Minibatch error= 26.7%
# 2017-11-27 17:22:07,087 Iter 2010, Minibatch Loss= 0.4003, Training Accuracy= 0.8096, Minibatch error= 19.0%
# 2017-11-27 17:22:17,409 Epoch 62, Average loss: 0.3570, learning rate: 0.0010
# 2017-11-27 17:22:19,082 Verification error= 18.4%, loss= 0.4085
# 2017-11-27 17:22:58,730 Iter 2020, Minibatch Loss= 0.3580, Training Accuracy= 0.8401, Minibatch error= 16.0%
# 2017-11-27 17:23:22,629 Iter 2030, Minibatch Loss= 0.4123, Training Accuracy= 0.7902, Minibatch error= 21.0%
# 2017-11-27 17:23:45,261 Iter 2040, Minibatch Loss= 0.5425, Training Accuracy= 0.6752, Minibatch error= 32.5%
# 2017-11-27 17:24:00,874 Epoch 63, Average loss: 0.3525, learning rate: 0.0010
# 2017-11-27 17:24:02,760 Verification error= 18.8%, loss= 0.3871
# 2017-11-27 17:24:40,266 Iter 2050, Minibatch Loss= 0.3560, Training Accuracy= 0.8373, Minibatch error= 16.3%
# 2017-11-27 17:25:02,759 Iter 2060, Minibatch Loss= 0.3466, Training Accuracy= 0.8489, Minibatch error= 15.1%
# 2017-11-27 17:25:27,381 Iter 2070, Minibatch Loss= 0.4200, Training Accuracy= 0.7796, Minibatch error= 22.0%
# 2017-11-27 17:25:47,039 Epoch 64, Average loss: 0.3376, learning rate: 0.0010
# 2017-11-27 17:25:48,755 Verification error= 26.6%, loss= 0.4931
# 2017-11-27 17:26:21,461 Iter 2080, Minibatch Loss= 0.4566, Training Accuracy= 0.7624, Minibatch error= 23.8%
# 2017-11-27 17:26:43,129 Iter 2090, Minibatch Loss= 0.3795, Training Accuracy= 0.8300, Minibatch error= 17.0%
# 2017-11-27 17:27:04,239 Iter 2100, Minibatch Loss= 0.3676, Training Accuracy= 0.8350, Minibatch error= 16.5%
# 2017-11-27 17:27:25,951 Iter 2110, Minibatch Loss= 0.3602, Training Accuracy= 0.8255, Minibatch error= 17.5%
# 2017-11-27 17:27:28,131 Epoch 65, Average loss: 0.3473, learning rate: 0.0010
# 2017-11-27 17:27:29,608 Verification error= 20.8%, loss= 0.4001
# 2017-11-27 17:28:18,950 Iter 2120, Minibatch Loss= 0.3418, Training Accuracy= 0.8528, Minibatch error= 14.7%
# 2017-11-27 17:28:41,505 Iter 2130, Minibatch Loss= 0.4067, Training Accuracy= 0.8051, Minibatch error= 19.5%
# 2017-11-27 17:29:04,234 Iter 2140, Minibatch Loss= 0.4072, Training Accuracy= 0.7902, Minibatch error= 21.0%
# 2017-11-27 17:29:10,742 Epoch 66, Average loss: 0.3449, learning rate: 0.0010
# 2017-11-27 17:29:12,278 Verification error= 22.2%, loss= 0.4247
# 2017-11-27 17:29:54,939 Iter 2150, Minibatch Loss= 0.3690, Training Accuracy= 0.8353, Minibatch error= 16.5%
# 2017-11-27 17:30:17,291 Iter 2160, Minibatch Loss= 0.4092, Training Accuracy= 0.7881, Minibatch error= 21.2%
# 2017-11-27 17:30:38,685 Iter 2170, Minibatch Loss= 0.3903, Training Accuracy= 0.8265, Minibatch error= 17.4%
# 2017-11-27 17:30:48,499 Epoch 67, Average loss: 0.3527, learning rate: 0.0010
# 2017-11-27 17:30:50,278 Verification error= 21.0%, loss= 0.4062
# 2017-11-27 17:31:29,641 Iter 2180, Minibatch Loss= 0.3773, Training Accuracy= 0.8132, Minibatch error= 18.7%
# 2017-11-27 17:31:53,983 Iter 2190, Minibatch Loss= 0.3962, Training Accuracy= 0.8078, Minibatch error= 19.2%
# 2017-11-27 17:32:16,902 Iter 2200, Minibatch Loss= 0.4795, Training Accuracy= 0.7333, Minibatch error= 26.7%
# 2017-11-27 17:32:32,240 Epoch 68, Average loss: 0.3545, learning rate: 0.0010
# 2017-11-27 17:32:34,407 Verification error= 20.2%, loss= 0.3985
# 2017-11-27 17:33:13,622 Iter 2210, Minibatch Loss= 0.3593, Training Accuracy= 0.8285, Minibatch error= 17.2%
# 2017-11-27 17:33:35,985 Iter 2220, Minibatch Loss= 0.3352, Training Accuracy= 0.8454, Minibatch error= 15.5%
# 2017-11-27 17:33:58,350 Iter 2230, Minibatch Loss= 0.3785, Training Accuracy= 0.8293, Minibatch error= 17.1%
# 2017-11-27 17:34:16,419 Epoch 69, Average loss: 0.3405, learning rate: 0.0010
# 2017-11-27 17:34:18,116 Verification error= 17.8%, loss= 0.3625
# 2017-11-27 17:34:49,287 Iter 2240, Minibatch Loss= 0.3259, Training Accuracy= 0.8495, Minibatch error= 15.0%
# 2017-11-27 17:35:11,339 Iter 2250, Minibatch Loss= 0.3404, Training Accuracy= 0.8514, Minibatch error= 14.9%
# 2017-11-27 17:35:33,357 Iter 2260, Minibatch Loss= 0.4992, Training Accuracy= 0.7239, Minibatch error= 27.6%
# 2017-11-27 17:35:55,412 Iter 2270, Minibatch Loss= 0.3857, Training Accuracy= 0.8304, Minibatch error= 17.0%
# 2017-11-27 17:35:57,769 Epoch 70, Average loss: 0.3315, learning rate: 0.0010
# 2017-11-27 17:35:59,404 Verification error= 21.0%, loss= 0.4090
# 2017-11-27 17:36:48,372 Iter 2280, Minibatch Loss= 0.3376, Training Accuracy= 0.8454, Minibatch error= 15.5%
# 2017-11-27 17:37:09,202 Iter 2290, Minibatch Loss= 0.5244, Training Accuracy= 0.6891, Minibatch error= 31.1%
# 2017-11-27 17:37:28,761 Iter 2300, Minibatch Loss= 0.3275, Training Accuracy= 0.8513, Minibatch error= 14.9%
# 2017-11-27 17:37:34,173 Epoch 71, Average loss: 0.3426, learning rate: 0.0010
# 2017-11-27 17:37:35,554 Verification error= 19.9%, loss= 0.3951
# 2017-11-27 17:38:19,875 Iter 2310, Minibatch Loss= 0.3023, Training Accuracy= 0.8760, Minibatch error= 12.4%
# 2017-11-27 17:38:42,824 Iter 2320, Minibatch Loss= 0.3894, Training Accuracy= 0.8112, Minibatch error= 18.9%
# 2017-11-27 17:39:05,500 Iter 2330, Minibatch Loss= 0.3425, Training Accuracy= 0.8329, Minibatch error= 16.7%
# 2017-11-27 17:39:16,374 Epoch 72, Average loss: 0.3483, learning rate: 0.0010
# 2017-11-27 17:39:18,023 Verification error= 16.4%, loss= 0.3471
# 2017-11-27 17:40:02,021 Iter 2340, Minibatch Loss= 0.3851, Training Accuracy= 0.8084, Minibatch error= 19.2%
# 2017-11-27 17:40:26,928 Iter 2350, Minibatch Loss= 0.3716, Training Accuracy= 0.8116, Minibatch error= 18.8%
# 2017-11-27 17:40:49,349 Iter 2360, Minibatch Loss= 0.3675, Training Accuracy= 0.8255, Minibatch error= 17.4%
# 2017-11-27 17:41:03,758 Epoch 73, Average loss: 0.3323, learning rate: 0.0010
# 2017-11-27 17:41:05,552 Verification error= 16.1%, loss= 0.3461
# 2017-11-27 17:41:43,020 Iter 2370, Minibatch Loss= 0.3637, Training Accuracy= 0.8348, Minibatch error= 16.5%
# 2017-11-27 17:42:06,730 Iter 2380, Minibatch Loss= 0.3439, Training Accuracy= 0.8395, Minibatch error= 16.0%
# 2017-11-27 17:42:31,262 Iter 2390, Minibatch Loss= 0.3817, Training Accuracy= 0.8145, Minibatch error= 18.6%
# 2017-11-27 17:42:51,155 Epoch 74, Average loss: 0.3425, learning rate: 0.0010
# 2017-11-27 17:42:52,869 Verification error= 19.6%, loss= 0.3854
# 2017-11-27 17:43:26,711 Iter 2400, Minibatch Loss= 0.3430, Training Accuracy= 0.8393, Minibatch error= 16.1%
# 2017-11-27 17:43:46,761 Iter 2410, Minibatch Loss= 0.3415, Training Accuracy= 0.8473, Minibatch error= 15.3%
# 2017-11-27 17:44:05,828 Iter 2420, Minibatch Loss= 0.3169, Training Accuracy= 0.8614, Minibatch error= 13.9%
# 2017-11-27 17:44:25,186 Iter 2430, Minibatch Loss= 0.3354, Training Accuracy= 0.8578, Minibatch error= 14.2%
# 2017-11-27 17:44:27,234 Epoch 75, Average loss: 0.3169, learning rate: 0.0010
# 2017-11-27 17:44:28,614 Verification error= 14.4%, loss= 0.3271
# 2017-11-27 17:45:17,281 Iter 2440, Minibatch Loss= 0.5806, Training Accuracy= 0.6311, Minibatch error= 36.9%
# 2017-11-27 17:45:42,963 Iter 2450, Minibatch Loss= 0.6241, Training Accuracy= 0.5795, Minibatch error= 42.1%
# 2017-11-27 17:46:06,821 Iter 2460, Minibatch Loss= 0.3774, Training Accuracy= 0.8100, Minibatch error= 19.0%
# 2017-11-27 17:46:13,680 Epoch 76, Average loss: 0.3491, learning rate: 0.0010
# 2017-11-27 17:46:15,270 Verification error= 19.6%, loss= 0.3849
# 2017-11-27 17:47:04,166 Iter 2470, Minibatch Loss= 0.4020, Training Accuracy= 0.8087, Minibatch error= 19.1%
# 2017-11-27 17:47:28,117 Iter 2480, Minibatch Loss= 0.3239, Training Accuracy= 0.8557, Minibatch error= 14.4%
# 2017-11-27 17:47:52,027 Iter 2490, Minibatch Loss= 0.4586, Training Accuracy= 0.7395, Minibatch error= 26.0%
# 2017-11-27 17:48:03,633 Epoch 77, Average loss: 0.3378, learning rate: 0.0010
# 2017-11-27 17:48:05,555 Verification error= 19.6%, loss= 0.3886
# 2017-11-27 17:48:48,216 Iter 2500, Minibatch Loss= 0.3546, Training Accuracy= 0.8249, Minibatch error= 17.5%
# 2017-11-27 17:49:11,789 Iter 2510, Minibatch Loss= 0.3326, Training Accuracy= 0.8536, Minibatch error= 14.6%
# 2017-11-27 17:49:32,931 Iter 2520, Minibatch Loss= 0.3407, Training Accuracy= 0.8427, Minibatch error= 15.7%
# 2017-11-27 17:49:46,734 Epoch 78, Average loss: 0.3427, learning rate: 0.0010
# 2017-11-27 17:49:48,366 Verification error= 21.2%, loss= 0.4022
# 2017-11-27 17:50:29,021 Iter 2530, Minibatch Loss= 0.3337, Training Accuracy= 0.8389, Minibatch error= 16.1%
# 2017-11-27 17:50:52,564 Iter 2540, Minibatch Loss= 0.3627, Training Accuracy= 0.8356, Minibatch error= 16.4%
# 2017-11-27 17:51:17,213 Iter 2550, Minibatch Loss= 0.3482, Training Accuracy= 0.8385, Minibatch error= 16.1%
# 2017-11-27 17:51:38,676 Epoch 79, Average loss: 0.3317, learning rate: 0.0010
# 2017-11-27 17:51:40,395 Verification error= 20.9%, loss= 0.4070
# 2017-11-27 17:52:19,111 Iter 2560, Minibatch Loss= 0.4120, Training Accuracy= 0.7825, Minibatch error= 21.7%
# 2017-11-27 17:52:43,610 Iter 2570, Minibatch Loss= 0.4714, Training Accuracy= 0.7367, Minibatch error= 26.3%
# 2017-11-27 17:53:06,990 Iter 2580, Minibatch Loss= 0.3440, Training Accuracy= 0.8377, Minibatch error= 16.2%
# 2017-11-27 17:53:29,282 Iter 2590, Minibatch Loss= 0.3843, Training Accuracy= 0.8149, Minibatch error= 18.5%
# 2017-11-27 17:53:31,630 Epoch 80, Average loss: 0.3372, learning rate: 0.0010
# 2017-11-27 17:53:33,321 Verification error= 16.4%, loss= 0.3380
# 2017-11-27 17:54:26,426 Iter 2600, Minibatch Loss= 0.3098, Training Accuracy= 0.8492, Minibatch error= 15.1%
# 2017-11-27 17:54:48,204 Iter 2610, Minibatch Loss= 0.3071, Training Accuracy= 0.8588, Minibatch error= 14.1%
# 2017-11-27 17:55:08,499 Iter 2620, Minibatch Loss= 0.3553, Training Accuracy= 0.8256, Minibatch error= 17.4%
# 2017-11-27 17:55:15,047 Epoch 81, Average loss: 0.3187, learning rate: 0.0010
# 2017-11-27 17:55:16,576 Verification error= 17.3%, loss= 0.3526
# 2017-11-27 17:56:05,959 Iter 2630, Minibatch Loss= 0.3466, Training Accuracy= 0.8354, Minibatch error= 16.5%
# 2017-11-27 17:56:29,821 Iter 2640, Minibatch Loss= 0.3083, Training Accuracy= 0.8675, Minibatch error= 13.2%
# 2017-11-27 17:56:54,643 Iter 2650, Minibatch Loss= 0.3404, Training Accuracy= 0.8306, Minibatch error= 16.9%
# 2017-11-27 17:57:06,228 Epoch 82, Average loss: 0.3312, learning rate: 0.0010
# 2017-11-27 17:57:07,978 Verification error= 16.7%, loss= 0.3384
# 2017-11-27 17:57:51,812 Iter 2660, Minibatch Loss= 0.3938, Training Accuracy= 0.8025, Minibatch error= 19.7%
# 2017-11-27 17:58:16,148 Iter 2670, Minibatch Loss= 0.3567, Training Accuracy= 0.8368, Minibatch error= 16.3%
# 2017-11-27 17:58:39,244 Iter 2680, Minibatch Loss= 0.3907, Training Accuracy= 0.8056, Minibatch error= 19.4%
# 2017-11-27 17:58:55,141 Epoch 83, Average loss: 0.3269, learning rate: 0.0010
# 2017-11-27 17:58:56,886 Verification error= 15.7%, loss= 0.3438
# 2017-11-27 17:59:38,537 Iter 2690, Minibatch Loss= 0.3356, Training Accuracy= 0.8432, Minibatch error= 15.7%
# 2017-11-27 18:00:01,976 Iter 2700, Minibatch Loss= 0.3608, Training Accuracy= 0.8383, Minibatch error= 16.2%
# 2017-11-27 18:00:25,665 Iter 2710, Minibatch Loss= 0.3281, Training Accuracy= 0.8400, Minibatch error= 16.0%
# 2017-11-27 18:00:44,832 Epoch 84, Average loss: 0.3237, learning rate: 0.0010
# 2017-11-27 18:00:46,608 Verification error= 17.5%, loss= 0.3608
# 2017-11-27 18:01:21,484 Iter 2720, Minibatch Loss= 0.3234, Training Accuracy= 0.8497, Minibatch error= 15.0%
# 2017-11-27 18:01:46,750 Iter 2730, Minibatch Loss= 0.3986, Training Accuracy= 0.7888, Minibatch error= 21.1%
# 2017-11-27 18:02:11,772 Iter 2740, Minibatch Loss= 0.3268, Training Accuracy= 0.8467, Minibatch error= 15.3%
# 2017-11-27 18:02:36,477 Iter 2750, Minibatch Loss= 0.3446, Training Accuracy= 0.8380, Minibatch error= 16.2%
# 2017-11-27 18:02:38,972 Epoch 85, Average loss: 0.3416, learning rate: 0.0010
# 2017-11-27 18:02:40,894 Verification error= 14.9%, loss= 0.3243
# 2017-11-27 18:03:36,238 Iter 2760, Minibatch Loss= 0.3355, Training Accuracy= 0.8424, Minibatch error= 15.8%
# 2017-11-27 18:03:57,407 Iter 2770, Minibatch Loss= 0.3319, Training Accuracy= 0.8481, Minibatch error= 15.2%
# 2017-11-27 18:04:18,784 Iter 2780, Minibatch Loss= 0.3004, Training Accuracy= 0.8572, Minibatch error= 14.3%
# 2017-11-27 18:04:25,041 Epoch 86, Average loss: 0.3271, learning rate: 0.0010
# 2017-11-27 18:04:26,578 Verification error= 17.5%, loss= 0.3535
# 2017-11-27 18:05:12,926 Iter 2790, Minibatch Loss= 0.3231, Training Accuracy= 0.8505, Minibatch error= 14.9%
# 2017-11-27 18:05:33,934 Iter 2800, Minibatch Loss= 0.3312, Training Accuracy= 0.8391, Minibatch error= 16.1%
# 2017-11-27 18:05:55,933 Iter 2810, Minibatch Loss= 0.3584, Training Accuracy= 0.8235, Minibatch error= 17.7%
# 2017-11-27 18:06:05,778 Epoch 87, Average loss: 0.3201, learning rate: 0.0010
# 2017-11-27 18:06:07,454 Verification error= 15.7%, loss= 0.3344
# 2017-11-27 18:06:52,183 Iter 2820, Minibatch Loss= 0.3431, Training Accuracy= 0.8451, Minibatch error= 15.5%
# 2017-11-27 18:07:16,981 Iter 2830, Minibatch Loss= 0.3860, Training Accuracy= 0.8178, Minibatch error= 18.2%
# 2017-11-27 18:07:40,174 Iter 2840, Minibatch Loss= 0.3617, Training Accuracy= 0.8168, Minibatch error= 18.3%
# 2017-11-27 18:07:55,285 Epoch 88, Average loss: 0.3416, learning rate: 0.0010
# 2017-11-27 18:07:57,220 Verification error= 18.0%, loss= 0.3674
# 2017-11-27 18:08:37,765 Iter 2850, Minibatch Loss= 0.3750, Training Accuracy= 0.8310, Minibatch error= 16.9%
# 2017-11-27 18:09:00,289 Iter 2860, Minibatch Loss= 0.3420, Training Accuracy= 0.8373, Minibatch error= 16.3%
# 2017-11-27 18:09:24,629 Iter 2870, Minibatch Loss= 0.3223, Training Accuracy= 0.8488, Minibatch error= 15.1%
# 2017-11-27 18:09:44,475 Epoch 89, Average loss: 0.3252, learning rate: 0.0010
# 2017-11-27 18:09:46,416 Verification error= 14.5%, loss= 0.3116
# 2017-11-27 18:10:24,104 Iter 2880, Minibatch Loss= 0.3462, Training Accuracy= 0.8414, Minibatch error= 15.9%
# 2017-11-27 18:10:49,047 Iter 2890, Minibatch Loss= 0.3012, Training Accuracy= 0.8584, Minibatch error= 14.2%
# 2017-11-27 18:11:13,418 Iter 2900, Minibatch Loss= 0.3225, Training Accuracy= 0.8476, Minibatch error= 15.2%
# 2017-11-27 18:11:36,924 Iter 2910, Minibatch Loss= 0.3449, Training Accuracy= 0.8407, Minibatch error= 15.9%
# 2017-11-27 18:11:39,127 Epoch 90, Average loss: 0.3170, learning rate: 0.0010
# 2017-11-27 18:11:40,717 Verification error= 15.8%, loss= 0.3309
# 2017-11-27 18:12:35,864 Iter 2920, Minibatch Loss= 0.3230, Training Accuracy= 0.8494, Minibatch error= 15.1%
# 2017-11-27 18:13:00,618 Iter 2930, Minibatch Loss= 0.3279, Training Accuracy= 0.8501, Minibatch error= 15.0%
# 2017-11-27 18:13:23,915 Iter 2940, Minibatch Loss= 0.3445, Training Accuracy= 0.8249, Minibatch error= 17.5%
# 2017-11-27 18:13:31,915 Epoch 91, Average loss: 0.3126, learning rate: 0.0010
# 2017-11-27 18:13:33,527 Verification error= 16.2%, loss= 0.3315
# 2017-11-27 18:14:24,396 Iter 2950, Minibatch Loss= 0.3187, Training Accuracy= 0.8440, Minibatch error= 15.6%
# 2017-11-27 18:14:45,529 Iter 2960, Minibatch Loss= 0.4057, Training Accuracy= 0.7844, Minibatch error= 21.6%
# 2017-11-27 18:15:07,292 Iter 2970, Minibatch Loss= 0.3481, Training Accuracy= 0.8278, Minibatch error= 17.2%
# 2017-11-27 18:15:17,776 Epoch 92, Average loss: 0.3208, learning rate: 0.0010
# 2017-11-27 18:15:19,632 Verification error= 17.4%, loss= 0.3527
# 2017-11-27 18:16:06,429 Iter 2980, Minibatch Loss= 0.3064, Training Accuracy= 0.8614, Minibatch error= 13.9%
# 2017-11-27 18:16:30,510 Iter 2990, Minibatch Loss= 0.3107, Training Accuracy= 0.8554, Minibatch error= 14.5%
# 2017-11-27 18:16:53,349 Iter 3000, Minibatch Loss= 0.3032, Training Accuracy= 0.8632, Minibatch error= 13.7%
# 2017-11-27 18:17:09,071 Epoch 93, Average loss: 0.3189, learning rate: 0.0010
# 2017-11-27 18:17:10,817 Verification error= 14.4%, loss= 0.3151
# 2017-11-27 18:17:53,646 Iter 3010, Minibatch Loss= 0.3401, Training Accuracy= 0.8406, Minibatch error= 15.9%
# 2017-11-27 18:18:16,086 Iter 3020, Minibatch Loss= 0.3132, Training Accuracy= 0.8619, Minibatch error= 13.8%
# 2017-11-27 18:18:39,873 Iter 3030, Minibatch Loss= 0.5819, Training Accuracy= 0.6603, Minibatch error= 34.0%
# 2017-11-27 18:18:58,477 Epoch 94, Average loss: 0.3167, learning rate: 0.0010
# 2017-11-27 18:19:00,272 Verification error= 15.1%, loss= 0.3202
# 2017-11-27 18:19:39,068 Iter 3040, Minibatch Loss= 0.2938, Training Accuracy= 0.8586, Minibatch error= 14.1%
# 2017-11-27 18:20:04,899 Iter 3050, Minibatch Loss= 0.3627, Training Accuracy= 0.8221, Minibatch error= 17.8%
# 2017-11-27 18:20:29,927 Iter 3060, Minibatch Loss= 0.3399, Training Accuracy= 0.8498, Minibatch error= 15.0%
# 2017-11-27 18:20:55,945 Iter 3070, Minibatch Loss= 0.4266, Training Accuracy= 0.7794, Minibatch error= 22.1%
# 2017-11-27 18:20:58,526 Epoch 95, Average loss: 0.3191, learning rate: 0.0010
# 2017-11-27 18:21:00,416 Verification error= 14.0%, loss= 0.3128
# 2017-11-27 18:21:59,995 Iter 3080, Minibatch Loss= 0.3466, Training Accuracy= 0.8347, Minibatch error= 16.5%
# 2017-11-27 18:22:24,131 Iter 3090, Minibatch Loss= 0.3418, Training Accuracy= 0.8465, Minibatch error= 15.4%
# 2017-11-27 18:22:47,546 Iter 3100, Minibatch Loss= 0.3316, Training Accuracy= 0.8469, Minibatch error= 15.3%
# 2017-11-27 18:22:54,326 Epoch 96, Average loss: 0.3143, learning rate: 0.0010
# 2017-11-27 18:22:56,233 Verification error= 16.0%, loss= 0.3337
# ...
# 2017-11-28 09:41:47,416 Iter 14970, Minibatch Loss= 0.1512, Training Accuracy= 0.9319, Minibatch error= 6.8%
# 2017-11-28 09:41:58,135 Epoch 467, Average loss: 0.1834, learning rate: 0.0010
# 2017-11-28 09:41:59,729 Verification error= 6.3%, loss= 0.1375
# 2017-11-28 09:44:08,412 Iter 14980, Minibatch Loss= 0.1653, Training Accuracy= 0.9226, Minibatch error= 7.7%
# 2017-11-28 09:44:31,318 Iter 14990, Minibatch Loss= 0.1410, Training Accuracy= 0.9361, Minibatch error= 6.4%
# 2017-11-28 09:44:54,493 Iter 15000, Minibatch Loss= 0.1718, Training Accuracy= 0.9201, Minibatch error= 8.0%
# 2017-11-28 09:45:08,938 Epoch 468, Average loss: 0.1816, learning rate: 0.0010
# 2017-11-28 09:45:10,642 Verification error= 6.1%, loss= 0.1337
# 2017-11-28 09:47:28,653 Iter 15010, Minibatch Loss= 0.1401, Training Accuracy= 0.9378, Minibatch error= 6.2%
# 2017-11-28 09:47:53,585 Iter 15020, Minibatch Loss= 0.1557, Training Accuracy= 0.9293, Minibatch error= 7.1%
# 2017-11-28 09:48:17,696 Iter 15030, Minibatch Loss= 0.1672, Training Accuracy= 0.9235, Minibatch error= 7.7%
# 2017-11-28 09:48:38,584 Epoch 469, Average loss: 0.1796, learning rate: 0.0010
# 2017-11-28 09:48:40,389 Verification error= 5.9%, loss= 0.1311
# 2017-11-28 09:50:53,852 Iter 15040, Minibatch Loss= 0.1495, Training Accuracy= 0.9337, Minibatch error= 6.6%
# 2017-11-28 09:51:18,846 Iter 15050, Minibatch Loss= 0.1518, Training Accuracy= 0.9332, Minibatch error= 6.7%
# 2017-11-28 09:51:44,268 Iter 15060, Minibatch Loss= 0.1692, Training Accuracy= 0.9200, Minibatch error= 8.0%
# 2017-11-28 09:52:08,430 Iter 15070, Minibatch Loss= 0.1406, Training Accuracy= 0.9366, Minibatch error= 6.3%
# 2017-11-28 09:52:10,854 Epoch 470, Average loss: 0.1815, learning rate: 0.0010
# 2017-11-28 09:52:12,468 Verification error= 6.1%, loss= 0.1336
# 2017-11-28 09:54:29,236 Iter 15080, Minibatch Loss= 0.1400, Training Accuracy= 0.9374, Minibatch error= 6.3%
# 2017-11-28 09:54:54,233 Iter 15090, Minibatch Loss= 0.1380, Training Accuracy= 0.9383, Minibatch error= 6.2%
# 2017-11-28 09:55:16,526 Iter 15100, Minibatch Loss= 0.1655, Training Accuracy= 0.9237, Minibatch error= 7.6%
# 2017-11-28 09:55:24,019 Epoch 471, Average loss: 0.1776, learning rate: 0.0010
# 2017-11-28 09:55:25,570 Verification error= 6.1%, loss= 0.1355
# 2017-11-28 09:57:40,355 Iter 15110, Minibatch Loss= 0.1775, Training Accuracy= 0.9171, Minibatch error= 8.3%
# 2017-11-28 09:58:03,531 Iter 15120, Minibatch Loss= 0.1302, Training Accuracy= 0.9408, Minibatch error= 5.9%
# 2017-11-28 09:58:26,652 Iter 15130, Minibatch Loss= 0.1425, Training Accuracy= 0.9347, Minibatch error= 6.5%
# 2017-11-28 09:58:37,193 Epoch 472, Average loss: 0.1793, learning rate: 0.0010
# 2017-11-28 09:58:38,681 Verification error= 6.2%, loss= 0.1383
# 2017-11-28 10:00:50,735 Iter 15140, Minibatch Loss= 0.1111, Training Accuracy= 0.9495, Minibatch error= 5.1%
# 2017-11-28 10:01:13,135 Iter 15150, Minibatch Loss= 0.1197, Training Accuracy= 0.9485, Minibatch error= 5.2%
# 2017-11-28 10:01:34,999 Iter 15160, Minibatch Loss= 0.1685, Training Accuracy= 0.9222, Minibatch error= 7.8%
# 2017-11-28 10:01:48,899 Epoch 473, Average loss: 0.1849, learning rate: 0.0010
# 2017-11-28 10:01:50,407 Verification error= 6.0%, loss= 0.1331
# 2017-11-28 10:04:10,210 Iter 15170, Minibatch Loss= 0.1656, Training Accuracy= 0.9246, Minibatch error= 7.5%
# 2017-11-28 10:04:34,677 Iter 15180, Minibatch Loss= 0.1632, Training Accuracy= 0.9244, Minibatch error= 7.6%
# 2017-11-28 10:04:58,836 Iter 15190, Minibatch Loss= 0.1523, Training Accuracy= 0.9322, Minibatch error= 6.8%
# 2017-11-28 10:05:18,463 Epoch 474, Average loss: 0.1889, learning rate: 0.0010
# 2017-11-28 10:05:19,988 Verification error= 6.1%, loss= 0.1333
# 2017-11-28 10:07:22,093 Iter 15200, Minibatch Loss= 0.1390, Training Accuracy= 0.9370, Minibatch error= 6.3%
# 2017-11-28 10:07:46,351 Iter 15210, Minibatch Loss= 0.1431, Training Accuracy= 0.9348, Minibatch error= 6.5%
# 2017-11-28 10:08:09,084 Iter 15220, Minibatch Loss= 0.1183, Training Accuracy= 0.9483, Minibatch error= 5.2%
# 2017-11-28 10:08:30,730 Iter 15230, Minibatch Loss= 0.1185, Training Accuracy= 0.9483, Minibatch error= 5.2%
# 2017-11-28 10:08:32,871 Epoch 475, Average loss: 0.1800, learning rate: 0.0010
# 2017-11-28 10:08:34,545 Verification error= 5.9%, loss= 0.1315
# 2017-11-28 10:10:56,090 Iter 15240, Minibatch Loss= 0.1658, Training Accuracy= 0.9224, Minibatch error= 7.8%
# 2017-11-28 10:11:19,183 Iter 15250, Minibatch Loss= 0.1595, Training Accuracy= 0.9287, Minibatch error= 7.1%
# 2017-11-28 10:11:42,076 Iter 15260, Minibatch Loss= 0.1433, Training Accuracy= 0.9358, Minibatch error= 6.4%
# 2017-11-28 10:11:48,607 Epoch 476, Average loss: 0.1853, learning rate: 0.0010
# 2017-11-28 10:11:50,509 Verification error= 6.3%, loss= 0.1385
# 2017-11-28 10:14:08,298 Iter 15270, Minibatch Loss= 0.1203, Training Accuracy= 0.9485, Minibatch error= 5.1%
# 2017-11-28 10:14:30,314 Iter 15280, Minibatch Loss= 0.1367, Training Accuracy= 0.9382, Minibatch error= 6.2%
# 2017-11-28 10:14:52,992 Iter 15290, Minibatch Loss= 0.1457, Training Accuracy= 0.9341, Minibatch error= 6.6%
# 2017-11-28 10:15:04,149 Epoch 477, Average loss: 0.1820, learning rate: 0.0010
# 2017-11-28 10:15:05,855 Verification error= 5.9%, loss= 0.1313
# 2017-11-28 10:17:12,763 Iter 15300, Minibatch Loss= 0.1316, Training Accuracy= 0.9401, Minibatch error= 6.0%
# 2017-11-28 10:17:35,791 Iter 15310, Minibatch Loss= 0.1447, Training Accuracy= 0.9345, Minibatch error= 6.6%
# 2017-11-28 10:17:58,430 Iter 15320, Minibatch Loss= 0.1383, Training Accuracy= 0.9382, Minibatch error= 6.2%
# 2017-11-28 10:18:16,445 Epoch 478, Average loss: 0.1859, learning rate: 0.0010
# 2017-11-28 10:18:18,262 Verification error= 6.2%, loss= 0.1358
# 2017-11-28 10:20:33,681 Iter 15330, Minibatch Loss= 0.1695, Training Accuracy= 0.9221, Minibatch error= 7.8%
# 2017-11-28 10:20:57,918 Iter 15340, Minibatch Loss= 0.1665, Training Accuracy= 0.9226, Minibatch error= 7.7%
# 2017-11-28 10:21:23,854 Iter 15350, Minibatch Loss= 0.1628, Training Accuracy= 0.9230, Minibatch error= 7.7%
# 2017-11-28 10:21:43,216 Epoch 479, Average loss: 0.1839, learning rate: 0.0010
# 2017-11-28 10:21:45,058 Verification error= 6.2%, loss= 0.1370
# 2017-11-28 10:23:49,554 Iter 15360, Minibatch Loss= 0.1407, Training Accuracy= 0.9372, Minibatch error= 6.3%
# 2017-11-28 10:24:13,842 Iter 15370, Minibatch Loss= 0.0888, Training Accuracy= 0.9597, Minibatch error= 4.0%
# 2017-11-28 10:24:35,891 Iter 15380, Minibatch Loss= 0.1497, Training Accuracy= 0.9306, Minibatch error= 6.9%
# 2017-11-28 10:24:57,284 Iter 15390, Minibatch Loss= 0.1315, Training Accuracy= 0.9414, Minibatch error= 5.9%
# 2017-11-28 10:24:59,346 Epoch 480, Average loss: 0.1763, learning rate: 0.0010
# 2017-11-28 10:25:00,868 Verification error= 5.8%, loss= 0.1279
# 2017-11-28 10:27:22,110 Iter 15400, Minibatch Loss= 0.1664, Training Accuracy= 0.9225, Minibatch error= 7.8%
# 2017-11-28 10:27:45,057 Iter 15410, Minibatch Loss= 0.1341, Training Accuracy= 0.9410, Minibatch error= 5.9%
# 2017-11-28 10:28:07,672 Iter 15420, Minibatch Loss= 0.1349, Training Accuracy= 0.9400, Minibatch error= 6.0%
# 2017-11-28 10:28:14,193 Epoch 481, Average loss: 0.1771, learning rate: 0.0010
# 2017-11-28 10:28:16,033 Verification error= 5.9%, loss= 0.1312
# 2017-11-28 10:30:34,585 Iter 15430, Minibatch Loss= 0.1335, Training Accuracy= 0.9399, Minibatch error= 6.0%
# 2017-11-28 10:30:57,911 Iter 15440, Minibatch Loss= 0.1627, Training Accuracy= 0.9245, Minibatch error= 7.6%
# 2017-11-28 10:31:22,066 Iter 15450, Minibatch Loss= 0.1585, Training Accuracy= 0.9286, Minibatch error= 7.1%
# 2017-11-28 10:31:32,899 Epoch 482, Average loss: 0.1801, learning rate: 0.0010
# 2017-11-28 10:31:34,532 Verification error= 6.1%, loss= 0.1345
# 2017-11-28 10:33:47,725 Iter 15460, Minibatch Loss= 0.1372, Training Accuracy= 0.9382, Minibatch error= 6.2%
# 2017-11-28 10:34:13,758 Iter 15470, Minibatch Loss= 0.1502, Training Accuracy= 0.9331, Minibatch error= 6.7%
# 2017-11-28 10:34:36,497 Iter 15480, Minibatch Loss= 0.1518, Training Accuracy= 0.9329, Minibatch error= 6.7%
# 2017-11-28 10:34:51,903 Epoch 483, Average loss: 0.1840, learning rate: 0.0010
# 2017-11-28 10:34:53,726 Verification error= 6.2%, loss= 0.1362
# 2017-11-28 10:37:06,074 Iter 15490, Minibatch Loss= 0.1448, Training Accuracy= 0.9326, Minibatch error= 6.7%
# 2017-11-28 10:37:29,303 Iter 15500, Minibatch Loss= 0.1687, Training Accuracy= 0.9219, Minibatch error= 7.8%
# 2017-11-28 10:37:54,015 Iter 15510, Minibatch Loss= 0.1525, Training Accuracy= 0.9333, Minibatch error= 6.7%
# 2017-11-28 10:38:13,856 Epoch 484, Average loss: 0.1835, learning rate: 0.0010
# 2017-11-28 10:38:15,637 Verification error= 6.0%, loss= 0.1332
# 2017-11-28 10:40:24,516 Iter 15520, Minibatch Loss= 0.1416, Training Accuracy= 0.9370, Minibatch error= 6.3%
# 2017-11-28 10:40:47,738 Iter 15530, Minibatch Loss= 0.1661, Training Accuracy= 0.9228, Minibatch error= 7.7%
# 2017-11-28 10:41:11,348 Iter 15540, Minibatch Loss= 0.1283, Training Accuracy= 0.9416, Minibatch error= 5.8%
# 2017-11-28 10:41:33,558 Iter 15550, Minibatch Loss= 0.1646, Training Accuracy= 0.9234, Minibatch error= 7.7%
# 2017-11-28 10:41:35,728 Epoch 485, Average loss: 0.1780, learning rate: 0.0010
# 2017-11-28 10:41:37,383 Verification error= 5.9%, loss= 0.1323
# 2017-11-28 10:43:55,464 Iter 15560, Minibatch Loss= 0.1545, Training Accuracy= 0.9288, Minibatch error= 7.1%
# 2017-11-28 10:44:20,330 Iter 15570, Minibatch Loss= 0.1624, Training Accuracy= 0.9247, Minibatch error= 7.5%
# 2017-11-28 10:44:42,278 Iter 15580, Minibatch Loss= 0.1317, Training Accuracy= 0.9409, Minibatch error= 5.9%
# 2017-11-28 10:44:48,609 Epoch 486, Average loss: 0.1779, learning rate: 0.0010
# 2017-11-28 10:44:50,318 Verification error= 5.9%, loss= 0.1311
# 2017-11-28 10:47:09,780 Iter 15590, Minibatch Loss= 0.1354, Training Accuracy= 0.9391, Minibatch error= 6.1%
# 2017-11-28 10:47:34,921 Iter 15600, Minibatch Loss= 0.0880, Training Accuracy= 0.9598, Minibatch error= 4.0%
# 2017-11-28 10:47:59,660 Iter 15610, Minibatch Loss= 0.1564, Training Accuracy= 0.9318, Minibatch error= 6.8%
# 2017-11-28 10:48:11,425 Epoch 487, Average loss: 0.1873, learning rate: 0.0010
# 2017-11-28 10:48:13,147 Verification error= 7.7%, loss= 0.1778
# 2017-11-28 10:50:28,367 Iter 15620, Minibatch Loss= 0.1523, Training Accuracy= 0.9356, Minibatch error= 6.4%
# 2017-11-28 10:50:52,148 Iter 15630, Minibatch Loss= 0.1589, Training Accuracy= 0.9266, Minibatch error= 7.3%
# 2017-11-28 10:51:15,948 Iter 15640, Minibatch Loss= 0.1718, Training Accuracy= 0.9216, Minibatch error= 7.8%
# 2017-11-28 10:51:30,563 Epoch 488, Average loss: 0.2153, learning rate: 0.0010
# 2017-11-28 10:51:32,341 Verification error= 6.3%, loss= 0.1390
# 2017-11-28 10:53:43,282 Iter 15650, Minibatch Loss= 0.0934, Training Accuracy= 0.9594, Minibatch error= 4.1%
# 2017-11-28 10:54:06,481 Iter 15660, Minibatch Loss= 0.1448, Training Accuracy= 0.9357, Minibatch error= 6.4%
# 2017-11-28 10:54:29,950 Iter 15670, Minibatch Loss= 0.0904, Training Accuracy= 0.9596, Minibatch error= 4.0%
# 2017-11-28 10:54:49,117 Epoch 489, Average loss: 0.1875, learning rate: 0.0010
# 2017-11-28 10:54:50,735 Verification error= 6.1%, loss= 0.1349
# 2017-11-28 10:56:55,385 Iter 15680, Minibatch Loss= 0.1325, Training Accuracy= 0.9400, Minibatch error= 6.0%
# 2017-11-28 10:57:19,536 Iter 15690, Minibatch Loss= 0.1720, Training Accuracy= 0.9211, Minibatch error= 7.9%
# 2017-11-28 10:57:42,038 Iter 15700, Minibatch Loss= 0.1364, Training Accuracy= 0.9385, Minibatch error= 6.2%
# 2017-11-28 10:58:05,295 Iter 15710, Minibatch Loss= 0.1474, Training Accuracy= 0.9322, Minibatch error= 6.8%
# 2017-11-28 10:58:07,609 Epoch 490, Average loss: 0.1781, learning rate: 0.0010
# 2017-11-28 10:58:09,136 Verification error= 5.8%, loss= 0.1311
# 2017-11-28 11:00:28,633 Iter 15720, Minibatch Loss= 0.1102, Training Accuracy= 0.9494, Minibatch error= 5.1%
# 2017-11-28 11:00:50,510 Iter 15730, Minibatch Loss= 0.1332, Training Accuracy= 0.9408, Minibatch error= 5.9%
# 2017-11-28 11:01:12,181 Iter 15740, Minibatch Loss= 0.1561, Training Accuracy= 0.9285, Minibatch error= 7.2%
# 2017-11-28 11:01:18,444 Epoch 491, Average loss: 0.1806, learning rate: 0.0010
# 2017-11-28 11:01:19,914 Verification error= 5.9%, loss= 0.1314
# 2017-11-28 11:03:38,570 Iter 15750, Minibatch Loss= 0.1296, Training Accuracy= 0.9438, Minibatch error= 5.6%
# 2017-11-28 11:04:01,495 Iter 15760, Minibatch Loss= 0.1235, Training Accuracy= 0.9453, Minibatch error= 5.5%
# 2017-11-28 11:04:24,062 Iter 15770, Minibatch Loss= 0.1675, Training Accuracy= 0.9220, Minibatch error= 7.8%
# 2017-11-28 11:04:34,940 Epoch 492, Average loss: 0.1817, learning rate: 0.0010
# 2017-11-28 11:04:36,603 Verification error= 6.2%, loss= 0.1358
# 2017-11-28 11:06:48,935 Iter 15780, Minibatch Loss= 0.1644, Training Accuracy= 0.9245, Minibatch error= 7.5%
# 2017-11-28 11:07:10,462 Iter 15790, Minibatch Loss= 0.1304, Training Accuracy= 0.9416, Minibatch error= 5.8%
# 2017-11-28 11:07:31,939 Iter 15800, Minibatch Loss= 0.1504, Training Accuracy= 0.9337, Minibatch error= 6.6%
# 2017-11-28 11:07:46,070 Epoch 493, Average loss: 0.1788, learning rate: 0.0010
# 2017-11-28 11:07:47,577 Verification error= 5.9%, loss= 0.1309
# 2017-11-28 11:09:56,327 Iter 15810, Minibatch Loss= 0.1380, Training Accuracy= 0.9386, Minibatch error= 6.1%
# 2017-11-28 11:10:19,596 Iter 15820, Minibatch Loss= 0.1625, Training Accuracy= 0.9256, Minibatch error= 7.4%
# 2017-11-28 11:10:42,186 Iter 15830, Minibatch Loss= 0.1360, Training Accuracy= 0.9380, Minibatch error= 6.2%
# 2017-11-28 11:11:01,020 Epoch 494, Average loss: 0.1793, learning rate: 0.0010
# 2017-11-28 11:11:02,622 Verification error= 5.9%, loss= 0.1316
# 2017-11-28 11:13:16,457 Iter 15840, Minibatch Loss= 0.1326, Training Accuracy= 0.9409, Minibatch error= 5.9%
# 2017-11-28 11:13:39,413 Iter 15850, Minibatch Loss= 0.1321, Training Accuracy= 0.9422, Minibatch error= 5.8%
# 2017-11-28 11:14:02,202 Iter 15860, Minibatch Loss= 0.1375, Training Accuracy= 0.9370, Minibatch error= 6.3%
# 2017-11-28 11:14:24,610 Iter 15870, Minibatch Loss= 0.1664, Training Accuracy= 0.9213, Minibatch error= 7.9%
# 2017-11-28 11:14:27,046 Epoch 495, Average loss: 0.1830, learning rate: 0.0010
# 2017-11-28 11:14:28,624 Verification error= 6.0%, loss= 0.1343
# 2017-11-28 11:16:52,655 Iter 15880, Minibatch Loss= 0.1226, Training Accuracy= 0.9447, Minibatch error= 5.5%
# 2017-11-28 11:17:14,978 Iter 15890, Minibatch Loss= 0.1721, Training Accuracy= 0.9186, Minibatch error= 8.1%
# 2017-11-28 11:17:37,124 Iter 15900, Minibatch Loss= 0.1234, Training Accuracy= 0.9450, Minibatch error= 5.5%
# 2017-11-28 11:17:43,032 Epoch 496, Average loss: 0.1799, learning rate: 0.0010
# 2017-11-28 11:17:44,846 Verification error= 6.0%, loss= 0.1339
# 2017-11-28 11:20:04,772 Iter 15910, Minibatch Loss= 0.1458, Training Accuracy= 0.9353, Minibatch error= 6.5%
# 2017-11-28 11:20:27,340 Iter 15920, Minibatch Loss= 0.1386, Training Accuracy= 0.9366, Minibatch error= 6.3%
# 2017-11-28 11:20:50,195 Iter 15930, Minibatch Loss= 0.1464, Training Accuracy= 0.9357, Minibatch error= 6.4%
# 2017-11-28 11:21:02,499 Epoch 497, Average loss: 0.1814, learning rate: 0.0010
# 2017-11-28 11:21:04,093 Verification error= 6.0%, loss= 0.1339
# 2017-11-28 11:23:24,515 Iter 15940, Minibatch Loss= 0.1376, Training Accuracy= 0.9380, Minibatch error= 6.2%
# 2017-11-28 11:23:49,392 Iter 15950, Minibatch Loss= 0.1359, Training Accuracy= 0.9393, Minibatch error= 6.1%
# 2017-11-28 11:24:12,994 Iter 15960, Minibatch Loss= 0.1355, Training Accuracy= 0.9388, Minibatch error= 6.1%
# 2017-11-28 11:24:28,462 Epoch 498, Average loss: 0.1846, learning rate: 0.0010
# 2017-11-28 11:24:30,334 Verification error= 5.9%, loss= 0.1310
# 2017-11-28 11:26:41,116 Iter 15970, Minibatch Loss= 0.1377, Training Accuracy= 0.9374, Minibatch error= 6.3%
# 2017-11-28 11:27:04,425 Iter 15980, Minibatch Loss= 0.1407, Training Accuracy= 0.9344, Minibatch error= 6.6%
# 2017-11-28 11:27:26,602 Iter 15990, Minibatch Loss= 0.1188, Training Accuracy= 0.9485, Minibatch error= 5.2%
# 2017-11-28 11:27:44,229 Epoch 499, Average loss: 0.1733, learning rate: 0.0010
# 2017-11-28 11:27:45,614 Verification error= 5.8%, loss= 0.1290
# 2017-11-28 11:29:49,505 Optimization Finished!

# %%
####################
# Testing result   # Un-scaled
####################

# %%
test_generator =image_util.SimpleDataProvider(X_test, Y_test, channels=3, n_class=2)

# %%
X_test, Y_test = test_generator(1)

# %%
prediction = net.predict("./out/model.cpkt", X_test)
# Out:
# INFO:tensorflow:Restoring parameters from ./out/model.cpkt
# 2017-11-28 11:33:25,508 Restoring parameters from ./out/model.cpkt
# 2017-11-28 11:33:44,214 Model restored from file: ./out/model.cpkt

# %%
fig, ax = plt.subplots(1, 3, sharex=True, sharey=True, figsize=(12,5))
ax[0].imshow(X_test[0,...,0], aspect="auto")
ax[1].imshow(Y_test[0,...,1], aspect="auto")
mask = prediction[0,...,1] > 0.9
ax[2].imshow(mask, aspect="auto")
ax[0].set_title("Input")
ax[1].set_title("Ground truth")
ax[2].set_title("Prediction")
fig.tight_layout()

plt.show()

# %%
print("PREDICTION",prediction.shape)
# Out:
# PREDICTION (1, 308, 308, 2)

# %%
print("Testing error rate: {:.2f}%".format(unet.error_rate(prediction, util.crop_to_shape(Y_test, prediction.shape))))
# Out:
# Testing error rate: 13.11%

# %%
img = util.combine_img_prediction(X_test,Y_test,prediction)
#util.save_image(img, "/Users/cesare.chung/int/retina_problem_Testing.png")
util.save_image(img, "D:/Cesare/tf_UNET_int/retina_problem.png")

# %%
####################
# Training result  # Un-scaled
####################

# %%
X_test, Y_test = data_provider(1)

prediction = net.predict("./out/model.cpkt", X_test)
# Out:
# INFO:tensorflow:Restoring parameters from ./out/model.cpkt
# 2017-11-28 11:37:26,708 Restoring parameters from ./out/model.cpkt
# 2017-11-28 11:37:40,017 Model restored from file: ./out/model.cpkt

# %%
print("Training error rate: {:.2f}%".format(unet.error_rate(prediction, util.crop_to_shape(Y_test, prediction.shape))))
# Out:
# Training error rate: 7.32%

# %%
img = util.combine_img_prediction(X_test,Y_test,prediction)
#util.save_image(img, "/Users/cesare.chung/int/retina_problem_Training.png")
util.save_image(img, "D:/Cesare/tf_UNET_int/retina_problem.png")

# %%
fig, ax = plt.subplots(1, 3, sharex=True, sharey=True, figsize=(12,5))
ax[0].imshow(X_test[0,...,0], aspect="auto")
ax[1].imshow(Y_test[0,...,1], aspect="auto")
mask = prediction[0,...,1] > 0.9
ax[2].imshow(mask, aspect="auto")
ax[0].set_title("Input")
ax[1].set_title("Ground truth")
ax[2].set_title("Prediction")
fig.tight_layout()

plt.show()
