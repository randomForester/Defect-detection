# %%
from tf_unet import unet, util, image_util
import glob
import cv2
import matplotlib.pyplot as plt
import numpy as np
#import scipy
from scipy import misc
# %matplotlib inline

# %%
#DATA_ROOT = "/Users/cesare.chung/int/01_CODE_UNET/NEW/"
#DATA_ROOT = "/Users/chung/int/"
DATA_ROOT = "D:/Cesare/tf_UNET_int/NEW/"

#masks_dir = sorted(glob.glob(DATA_ROOT+"/trainData_tftf/resize/*_mask.gif"))
#imgs_dir  = sorted(glob.glob(DATA_ROOT+"/trainData_tftf/resize/*_training.tif"))

masks_dir = sorted(glob.glob(DATA_ROOT+"/trainData_tftf/resize2/*_mask_resized_mask.gif"))
imgs_dir  = sorted(glob.glob(DATA_ROOT+"/trainData_tftf/resize2/*_training_resized_training.tif"))

# %%
X_data=[]
for index,entry in enumerate(imgs_dir):
    img = misc.imread(entry)
    X_data.append(img)

Y_data=[]
for index,entry in enumerate(masks_dir):
    img = misc.imread(entry)
    Y_data.append(img)

X_data=np.array(X_data)
Y_data=np.array(Y_data)

plt.imshow(X_data[4,...,2], aspect="auto")   # X_data[i,...,j]. i = 1,..., number of samples; j = 1,2,3
plt.show()
plt.imshow(Y_data[4,...,], aspect="auto",cmap='gray')
plt.show()

# %%
#preparing data loading

#data_provider = image_util.ImageDataProvider(DATA_ROOT+"/trainData_tf/*.jpg", data_suffix="_img.jpg", mask_suffix="_mask.jpg")
#data_provider.n_class = 2

#data_provider = image_util.ImageDataProvider(DATA_ROOT+"/trainData_tftf/resize/*",data_suffix="_training.tif", mask_suffix="_mask.gif")
data_provider = image_util.ImageDataProvider(DATA_ROOT+"/trainData_tftf/resize2/*",data_suffix="_training_resized_training.tif", mask_suffix="_mask_resized_mask.gif")
#data_provider.n_class = 2

#search_path = DATA_ROOT+"/trainData_tf2/*"
#data_provider = image_util.ImageDataProvider(search_path, a_min=0, a_max=255, data_suffix="_training.tif", mask_suffix="_mask.gif")
#data_provider.n_class = 2
# Out:
# Number of files used: 20

# %%
x_test, y_test = data_provider(4)

fig, ax = plt.subplots(1,2, sharey=True, figsize=(8,4))
ax[0].imshow(x_test[0,...,0], aspect="auto")
ax[1].imshow(y_test[0,...,1], aspect="auto")
plt.show()

# %%
print(x_test.shape)
print(y_test.shape)

print(data_provider.channels)
print(data_provider.n_class)
# Out:
# (4, 550, 550, 3)
# (4, 550, 550, 2)
# 3
# 2

# %%
#setup & training

#net = unet.Unet(layers=3, features_root=64, channels=3, n_class=2)

net = unet.Unet(channels=data_provider.channels, n_class=data_provider.n_class, layers=3, features_root=64)
trainer = unet.Trainer(net, optimizer="adam")

#net = unet.Unet(channels=data_provider.channels,n_class=data_provider.n_class)
#trainer = unet.Trainer(net, optimizer="momentum", opt_kwargs=dict(momentum=0.2))

#z,y=data_provider(1)
# Out:
# 2017-10-30 12:02:00,823 Layers 3, features 64, filter size 3x3, pool size: 2x2

# %%
path = trainer.train(data_provider, output_path="out", training_iters=20, epochs=10,dropout=0.5, display_step=5)
# Out:
# 2017-10-30 12:02:14,881 Removing 'D:\Cesare\tf_UNET_int\prediction'
# 2017-10-30 12:02:14,882 Removing 'D:\Cesare\tf_UNET_int\out'
# 2017-10-30 12:02:14,883 Allocating 'D:\Cesare\tf_UNET_int\prediction'
# 2017-10-30 12:02:14,884 Allocating 'D:\Cesare\tf_UNET_int\out'
# 2017-10-30 12:03:08,845 Verification error= 79.4%, loss= 0.7127
# 2017-10-30 12:03:20,572 Start optimization
# 2017-10-30 12:03:57,801 Iter 0, Minibatch Loss= 0.6226, Training Accuracy= 0.7647, Minibatch error= 23.5%
# 2017-10-30 12:04:15,815 Iter 5, Minibatch Loss= 0.5914, Training Accuracy= 0.7932, Minibatch error= 20.7%
# 2017-10-30 12:04:30,877 Iter 10, Minibatch Loss= 0.6010, Training Accuracy= 0.8044, Minibatch error= 19.6%
# 2017-10-30 12:04:48,434 Iter 15, Minibatch Loss= 0.5339, Training Accuracy= 0.8206, Minibatch error= 17.9%
# 2017-10-30 12:04:59,216 Epoch 0, Average loss: 0.5979, learning rate: 0.0010
# 2017-10-30 12:05:01,921 Verification error= 20.5%, loss= 0.5076
# 2017-10-30 12:05:16,357 Iter 20, Minibatch Loss= 0.4920, Training Accuracy= 0.8063, Minibatch error= 19.4%
# 2017-10-30 12:05:34,633 Iter 25, Minibatch Loss= 0.4745, Training Accuracy= 0.8166, Minibatch error= 18.3%
# 2017-10-30 12:05:52,179 Iter 30, Minibatch Loss= 0.5325, Training Accuracy= 0.7936, Minibatch error= 20.6%
# 2017-10-30 12:06:08,498 Iter 35, Minibatch Loss= 0.5103, Training Accuracy= 0.8166, Minibatch error= 18.3%
# 2017-10-30 12:06:19,180 Epoch 1, Average loss: 0.5194, learning rate: 0.0010
# 2017-10-30 12:06:21,858 Verification error= 20.5%, loss= 0.5028
# 2017-10-30 12:06:37,374 Iter 40, Minibatch Loss= 0.5005, Training Accuracy= 0.7932, Minibatch error= 20.7%
# 2017-10-30 12:06:54,765 Iter 45, Minibatch Loss= 0.5161, Training Accuracy= 0.7647, Minibatch error= 23.5%
# 2017-10-30 12:07:11,081 Iter 50, Minibatch Loss= 0.4895, Training Accuracy= 0.8063, Minibatch error= 19.4%
# 2017-10-30 12:07:29,161 Iter 55, Minibatch Loss= 0.5079, Training Accuracy= 0.8109, Minibatch error= 18.9%
# 2017-10-30 12:07:40,190 Epoch 2, Average loss: 0.4863, learning rate: 0.0010
# 2017-10-30 12:07:42,931 Verification error= 20.5%, loss= 0.5080
# 2017-10-30 12:07:59,848 Iter 60, Minibatch Loss= 0.5000, Training Accuracy= 0.8051, Minibatch error= 19.5%
# 2017-10-30 12:08:15,731 Iter 65, Minibatch Loss= 0.5086, Training Accuracy= 0.7827, Minibatch error= 21.7%
# 2017-10-30 12:08:36,265 Iter 70, Minibatch Loss= 0.4565, Training Accuracy= 0.8206, Minibatch error= 17.9%
# 2017-10-30 12:08:53,326 Iter 75, Minibatch Loss= 0.4749, Training Accuracy= 0.8206, Minibatch error= 17.9%
# 2017-10-30 12:09:04,718 Epoch 3, Average loss: 0.4468, learning rate: 0.0010
# 2017-10-30 12:09:07,323 Verification error= 20.5%, loss= 0.4967
# 2017-10-30 12:09:23,482 Iter 80, Minibatch Loss= 0.5057, Training Accuracy= 0.7894, Minibatch error= 21.1%
# 2017-10-30 12:09:40,448 Iter 85, Minibatch Loss= 0.4964, Training Accuracy= 0.8051, Minibatch error= 19.5%
# 2017-10-30 12:09:56,613 Iter 90, Minibatch Loss= 0.4946, Training Accuracy= 0.7899, Minibatch error= 21.0%
# 2017-10-30 12:10:13,729 Iter 95, Minibatch Loss= 0.5020, Training Accuracy= 0.7936, Minibatch error= 20.6%
# 2017-10-30 12:10:24,763 Epoch 4, Average loss: 0.4583, learning rate: 0.0010
# 2017-10-30 12:10:28,420 Verification error= 20.5%, loss= 0.4955
# 2017-10-30 12:10:44,647 Iter 100, Minibatch Loss= 0.4865, Training Accuracy= 0.7899, Minibatch error= 21.0%
# 2017-10-30 12:11:02,823 Iter 105, Minibatch Loss= 0.4928, Training Accuracy= 0.8166, Minibatch error= 18.3%
# 2017-10-30 12:11:20,918 Iter 110, Minibatch Loss= 0.4886, Training Accuracy= 0.8276, Minibatch error= 17.2%
# 2017-10-30 12:11:37,096 Iter 115, Minibatch Loss= 0.4927, Training Accuracy= 0.8109, Minibatch error= 18.9%
# 2017-10-30 12:11:48,286 Epoch 5, Average loss: 0.4489, learning rate: 0.0010
# 2017-10-30 12:11:50,776 Verification error= 20.5%, loss= 0.4948
# 2017-10-30 12:12:07,596 Iter 120, Minibatch Loss= 0.4984, Training Accuracy= 0.7936, Minibatch error= 20.6%
# 2017-10-30 12:12:24,593 Iter 125, Minibatch Loss= 0.4858, Training Accuracy= 0.8247, Minibatch error= 17.5%
# 2017-10-30 12:12:42,230 Iter 130, Minibatch Loss= 0.4930, Training Accuracy= 0.8063, Minibatch error= 19.4%
# 2017-10-30 12:13:00,162 Iter 135, Minibatch Loss= 0.5140, Training Accuracy= 0.7503, Minibatch error= 25.0%
# 2017-10-30 12:13:11,363 Epoch 6, Average loss: 0.4433, learning rate: 0.0010
# 2017-10-30 12:13:13,989 Verification error= 20.5%, loss= 0.4948
# 2017-10-30 12:13:33,450 Iter 140, Minibatch Loss= 0.4968, Training Accuracy= 0.7936, Minibatch error= 20.6%
# 2017-10-30 12:13:50,650 Iter 145, Minibatch Loss= 0.4984, Training Accuracy= 0.7894, Minibatch error= 21.1%
# 2017-10-30 12:14:07,191 Iter 150, Minibatch Loss= 0.4917, Training Accuracy= 0.8121, Minibatch error= 18.8%
# 2017-10-30 12:14:25,059 Iter 155, Minibatch Loss= 0.4937, Training Accuracy= 0.8109, Minibatch error= 18.9%
# 2017-10-30 12:14:38,903 Epoch 7, Average loss: 0.4542, learning rate: 0.0010
# 2017-10-30 12:14:42,721 Verification error= 20.5%, loss= 0.4962
# 2017-10-30 12:15:13,144 Iter 160, Minibatch Loss= 0.4981, Training Accuracy= 0.7932, Minibatch error= 20.7%
# 2017-10-30 12:15:34,443 Iter 165, Minibatch Loss= 0.4733, Training Accuracy= 0.8635, Minibatch error= 13.7%
# 2017-10-30 12:15:56,417 Iter 170, Minibatch Loss= 0.4697, Training Accuracy= 0.8584, Minibatch error= 14.2%
# 2017-10-30 12:16:19,351 Iter 175, Minibatch Loss= 0.5066, Training Accuracy= 0.7647, Minibatch error= 23.5%
# 2017-10-30 12:16:33,485 Epoch 8, Average loss: 0.4470, learning rate: 0.0010
# 2017-10-30 12:16:36,503 Verification error= 20.5%, loss= 0.4971
# 2017-10-30 12:17:03,939 Iter 180, Minibatch Loss= 0.4936, Training Accuracy= 0.8044, Minibatch error= 19.6%
# 2017-10-30 12:17:25,954 Iter 185, Minibatch Loss= 0.4988, Training Accuracy= 0.7894, Minibatch error= 21.1%
# 2017-10-30 12:17:47,708 Iter 190, Minibatch Loss= 0.4987, Training Accuracy= 0.7827, Minibatch error= 21.7%
# 2017-10-30 12:18:09,224 Iter 195, Minibatch Loss= 0.4804, Training Accuracy= 0.8166, Minibatch error= 18.3%
# 2017-10-30 12:18:23,833 Epoch 9, Average loss: 0.4369, learning rate: 0.0010
# 2017-10-30 12:18:27,077 Verification error= 20.5%, loss= 0.4904
# 2017-10-30 12:18:52,307 Optimization Finished!

# %%
prediction = net.predict("./out/model.cpkt", x_test)
# Out:
# INFO:tensorflow:Restoring parameters from ./out/model.cpkt
# 2017-10-30 12:43:16,542 Restoring parameters from ./out/model.cpkt
# 2017-10-30 12:43:18,428 Model restored from file: ./out/model.cpkt

# %%
fig, ax = plt.subplots(1, 3, sharex=True, sharey=True, figsize=(12,5))
ax[0].imshow(x_test[0,...,0], aspect="auto")
ax[1].imshow(y_test[0,...,1], aspect="auto")
mask = prediction[0,...,1] > 0.9
ax[2].imshow(mask, aspect="auto")
ax[0].set_title("Input")
ax[1].set_title("Ground truth")
ax[2].set_title("Prediction")
fig.tight_layout()

plt.show()

# %%
unet.error_rate(prediction, util.crop_to_shape(y_test, prediction.shape))
# Out:
# 18.437383749767505

# %%
img = util.combine_img_prediction(x_test,y_test,prediction)
util.save_image(img, "D:/Cesare/tf_UNET_int/retina_problem.png")

#util.save_image(img, "/Users/chung/int/retina_problem.png")
