# %%
import PIL
from PIL import Image

# %%
basewidth = 500
img = Image.open("/Users/cesare.chung/int/01_CODE_UNET/NEW/trainData_tftf/resize/1.tif")
img.size
# Out:
# (565, 584)

# %%
wpercent = (basewidth / float(img.size[0]))
hsize = int((float(img.size[1]) * float(wpercent)))
img = img.resize((basewidth, hsize), PIL.Image.ANTIALIAS)
img.save("/Users/cesare.chung/int/01_CODE_UNET/NEW/trainData_tftf/resize/1_resized_image.tif")

# %%
#img.crop
img.size
# Out:
# (500, 516)

# %%
img
# Out:
# <PIL.Image.Image image mode=RGB size=500x516 at 0x103079160>

# %%
"""
baseheight = 560
img = Image.open("/Users/cesare.chung/int/01_CODE_UNET/NEW/trainData_tftf/resize/1.tif")
hpercent = (baseheight / float(img.size[1]))
wsize = int((float(img.size[0]) * float(hpercent)))
img = img.resize((wsize, baseheight), PIL.Image.ANTIALIAS)
img.save("/Users/cesare.chung/int/01_CODE_UNET/NEW/trainData_tftf/resize/1_resized_image.tif")
"""
# Out:
# '\nbaseheight = 560\nimg = Image.open("/Users/cesare.chung/int/01_CODE_UNET/NEW/trainData_tftf/resize/1.tif")\nhpercent = (baseheight / float(img.size[1]))\nwsize = int((float(img.size[0]) * float(hpercent)))\nimg = img.resize((wsize, baseheight), PIL.Image.ANTIALIAS)\nimg.save("/Users/cesare.chung/int/01_CODE_UNET/NEW/trainData_tftf/resize/1_resized_image.tif")\n'

# %%
import glob

DATA_ROOT = "/Users/cesare.chung/int/01_CODE_UNET/NEW/"

imgs_dir  = sorted(glob.glob(DATA_ROOT+"/trainData_tf2/*_training.tif"))
    
basewidth = 500
X_data=[]
for index,entry in enumerate(imgs_dir):
    img = Image.open(entry)
    wpercent = (basewidth / float(img.size[0]))
    hsize = int((float(img.size[1]) * float(wpercent)))
    img = img.resize((basewidth, hsize), PIL.Image.ANTIALIAS)
    X_data.append(img)

# %%
X_data[2]
# Out:
# <PIL.Image.Image image mode=RGB size=500x516 at 0x1035FE2B0>

# %%
X_data
# Out:
# [<PIL.Image.Image image mode=RGB size=500x516 at 0x103085D68>,
#  <PIL.Image.Image image mode=RGB size=500x516 at 0x1035FE208>,
#  <PIL.Image.Image image mode=RGB size=500x516 at 0x1035FE2B0>,
#  <PIL.Image.Image image mode=RGB size=500x516 at 0x1035FE518>,
#  <PIL.Image.Image image mode=RGB size=500x516 at 0x1035FE7B8>,
#  <PIL.Image.Image image mode=RGB size=500x516 at 0x1035FEA58>,
#  <PIL.Image.Image image mode=RGB size=500x516 at 0x1035FECF8>,
#  <PIL.Image.Image image mode=RGB size=500x516 at 0x1035FEF98>,
#  <PIL.Image.Image image mode=RGB size=500x516 at 0x1036031D0>,
#  <PIL.Image.Image image mode=RGB size=500x516 at 0x103603278>,
#  <PIL.Image.Image image mode=RGB size=500x516 at 0x103603748>,
#  <PIL.Image.Image image mode=RGB size=500x516 at 0x1036039E8>,
#  <PIL.Image.Image image mode=RGB size=500x516 at 0x103603C88>,
#  <PIL.Image.Image image mode=RGB size=500x516 at 0x103603F28>,
#  <PIL.Image.Image image mode=RGB size=500x516 at 0x103604208>,
# ...

# %%
X_data[1].size
# Out:
# (500, 516)

# %%
X_data[0].save("/Users/cesare.chung/int/01_CODE_UNET/NEW/trainData_tftf/resize/21_training.tif")
X_data[1].save("/Users/cesare.chung/int/01_CODE_UNET/NEW/trainData_tftf/resize/22_training.tif")
X_data[2].save("/Users/cesare.chung/int/01_CODE_UNET/NEW/trainData_tftf/resize/23_training.tif")
X_data[3].save("/Users/cesare.chung/int/01_CODE_UNET/NEW/trainData_tftf/resize/24_training.tif")
X_data[4].save("/Users/cesare.chung/int/01_CODE_UNET/NEW/trainData_tftf/resize/25_training.tif")

# %%
for i in range(0,20):
    print(X_data[i].size)
# Out:
# (500, 516)
# (500, 516)
# (500, 516)
# (500, 516)
# (500, 516)
# (500, 516)
# (500, 516)
# (500, 516)
# (500, 516)
# (500, 516)
# (500, 516)
# (500, 516)
# (500, 516)
# (500, 516)
# (500, 516)
# (500, 516)
# (500, 516)
# (500, 516)
# (500, 516)
# (500, 516)

# %%
for i in [1,19]:
    print(X_data[i].size)
# Out:
# (500, 516)
# (500, 516)

# %%
for i in range(10,25):
    print(X_data[i].size)
# Out:
# (500, 516)
# (500, 516)
# (500, 516)
# (500, 516)
# (500, 516)
# (500, 516)
# (500, 516)
# (500, 516)
# (500, 516)
# (500, 516)
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-14-66d122e30058> in <module>()
#       1 for i in range(10,25):
# ----> 2     print(X_data[i].size)
#
# IndexError: list index out of range
