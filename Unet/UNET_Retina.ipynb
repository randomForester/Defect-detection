# %%
from PIL import Image
im = Image.open("/Users/cesare.chung/int/01_CODE_UNET/NEW/trainData_tftf/1.gif")

from __future__ import print_function
print(im.format, im.size, im.mode)

im
# Out:
# GIF (565, 584) L
# <PIL.GifImagePlugin.GifImageFile image mode=L size=565x584 at 0x109BE8710>

# %%
im = Image.open("/Users/cesare.chung/int/01_CODE_UNET/NEW/trainData_tftf/1.tif")

from __future__ import print_function
print(im.format, im.size, im.mode)

#im.show()
im
# Out:
# TIFF (565, 584) RGB
# <PIL.TiffImagePlugin.TiffImageFile image mode=RGB size=565x584 at 0x1095B7C50>
