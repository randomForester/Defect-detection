# %%
from tf_unet import unet, util, image_util
import glob
import cv2
import matplotlib.pyplot as plt
import numpy as np
#import scipy
from scipy import misc
# %matplotlib inline

# %%
#DATA_ROOT = "/Users/cesare.chung/int/01_CODE_UNET/NEW/"
DATA_ROOT = "D:/Cesare/tf_UNET_int/JPEGImages_used"

#masks_dir = sorted(glob.glob(DATA_ROOT+"/dataset/JPEGImages_used/resize/*_mask_viz_resized_mask_viz.png"))
masks_dir = sorted(glob.glob(DATA_ROOT+"/resize/*_mask_resized_mask.png"))
imgs_dir  = sorted(glob.glob(DATA_ROOT+"/resize/*_training_resized_training.png"))

# %%
X_data=[]
for index,entry in enumerate(imgs_dir):
    img = misc.imread(entry)
    X_data.append(img)

Y_data=[]
for index,entry in enumerate(masks_dir):
    img = misc.imread(entry)
    Y_data.append(img)

X_data=np.array(X_data)
Y_data=np.array(Y_data)

plt.imshow(X_data[1,...,2], aspect="auto")   # X_data[i,...,j]. i = 1,..., number of samples; j = 1,2,3
plt.show()
plt.imshow(Y_data[1,...,], aspect="auto",cmap='gray')
plt.show()

# %%
data_provider = image_util.ImageDataProvider(DATA_ROOT+"/resize/*",data_suffix="_training_resized_training.png", mask_suffix="_mask_resized_mask.png")
# Out:
# Number of files used: 10

# %%
x_test, y_test = data_provider(1)

fig, ax = plt.subplots(1,2, sharey=True, figsize=(8,4))
ax[0].imshow(x_test[0,...,0], aspect="auto")
ax[1].imshow(y_test[0,...,1], aspect="auto",cmap='gray')
plt.show()

# %%
print(x_test.shape)
print(y_test.shape)

print(data_provider.channels)
print(data_provider.n_class)
# Out:
# (1, 550, 320, 3)
# (1, 550, 320, 2)
# 3
# 2

# %%
net = unet.Unet(channels=data_provider.channels, n_class=data_provider.n_class, layers=3, features_root=64)

trainer = unet.Trainer(net, optimizer="adam")
# Out:
# 2017-11-06 17:53:50,212 Layers 3, features 64, filter size 3x3, pool size: 2x2

# %%
path = trainer.train(data_provider, output_path="out", training_iters=32, epochs=10,dropout=0.75, display_step=2)
# Out:
# 2017-11-06 17:54:05,403 Removing 'D:\Cesare\tf_UNET_int\prediction'
# 2017-11-06 17:54:05,404 Removing 'D:\Cesare\tf_UNET_int\out'
# 2017-11-06 17:54:05,412 Allocating 'D:\Cesare\tf_UNET_int\prediction'
# 2017-11-06 17:54:05,413 Allocating 'D:\Cesare\tf_UNET_int\out'
# 2017-11-06 17:55:08,598 Verification error= 29.4%, loss= 0.6906
# 2017-11-06 17:55:17,090 Start optimization
# 2017-11-06 17:55:39,254 Iter 0, Minibatch Loss= 0.5786, Training Accuracy= 0.9464, Minibatch error= 5.4%
# 2017-11-06 17:55:47,782 Iter 2, Minibatch Loss= 0.3573, Training Accuracy= 0.9411, Minibatch error= 5.9%
# 2017-11-06 17:55:55,642 Iter 4, Minibatch Loss= 0.3602, Training Accuracy= 0.9321, Minibatch error= 6.8%
# 2017-11-06 17:56:03,361 Iter 6, Minibatch Loss= 0.4198, Training Accuracy= 0.9429, Minibatch error= 5.7%
# 2017-11-06 17:56:11,950 Iter 8, Minibatch Loss= 0.3919, Training Accuracy= 0.9358, Minibatch error= 6.4%
# 2017-11-06 17:56:19,765 Iter 10, Minibatch Loss= 0.3117, Training Accuracy= 0.9340, Minibatch error= 6.6%
# 2017-11-06 17:56:28,597 Iter 12, Minibatch Loss= 0.2293, Training Accuracy= 0.9411, Minibatch error= 5.9%
# 2017-11-06 17:56:37,352 Iter 14, Minibatch Loss= 0.2292, Training Accuracy= 0.9429, Minibatch error= 5.7%
# 2017-11-06 17:56:44,967 Iter 16, Minibatch Loss= 0.2310, Training Accuracy= 0.9429, Minibatch error= 5.7%
# 2017-11-06 17:56:53,452 Iter 18, Minibatch Loss= 0.2285, Training Accuracy= 0.9393, Minibatch error= 6.1%
# 2017-11-06 17:57:01,551 Iter 20, Minibatch Loss= 0.2480, Training Accuracy= 0.9321, Minibatch error= 6.8%
# 2017-11-06 17:57:09,604 Iter 22, Minibatch Loss= 0.2380, Training Accuracy= 0.9411, Minibatch error= 5.9%
# 2017-11-06 17:57:17,154 Iter 24, Minibatch Loss= 0.2380, Training Accuracy= 0.9429, Minibatch error= 5.7%
# 2017-11-06 17:57:24,898 Iter 26, Minibatch Loss= 0.2363, Training Accuracy= 0.9412, Minibatch error= 5.9%
# 2017-11-06 17:57:32,842 Iter 28, Minibatch Loss= 0.2217, Training Accuracy= 0.9429, Minibatch error= 5.7%
# 2017-11-06 17:57:40,310 Iter 30, Minibatch Loss= 0.2116, Training Accuracy= 0.9447, Minibatch error= 5.5%
# 2017-11-06 17:57:43,255 Epoch 0, Average loss: 0.3100, learning rate: 0.0010
# 2017-11-06 17:57:45,265 Verification error= 6.0%, loss= 0.2228
# 2017-11-06 17:58:01,496 Iter 32, Minibatch Loss= 0.2051, Training Accuracy= 0.9464, Minibatch error= 5.4%
# 2017-11-06 17:58:09,244 Iter 34, Minibatch Loss= 0.2195, Training Accuracy= 0.9411, Minibatch error= 5.9%
# 2017-11-06 17:58:17,582 Iter 36, Minibatch Loss= 0.2136, Training Accuracy= 0.9429, Minibatch error= 5.7%
# 2017-11-06 17:58:26,046 Iter 38, Minibatch Loss= 0.2184, Training Accuracy= 0.9412, Minibatch error= 5.9%
# 2017-11-06 17:58:33,715 Iter 40, Minibatch Loss= 0.2059, Training Accuracy= 0.9464, Minibatch error= 5.4%
# 2017-11-06 17:58:42,281 Iter 42, Minibatch Loss= 0.2259, Training Accuracy= 0.9393, Minibatch error= 6.1%
# 2017-11-06 17:58:50,120 Iter 44, Minibatch Loss= 0.2213, Training Accuracy= 0.9411, Minibatch error= 5.9%
# 2017-11-06 17:58:57,395 Iter 46, Minibatch Loss= 0.2370, Training Accuracy= 0.9340, Minibatch error= 6.6%
# 2017-11-06 17:59:05,062 Iter 48, Minibatch Loss= 0.2307, Training Accuracy= 0.9358, Minibatch error= 6.4%
# 2017-11-06 17:59:13,316 Iter 50, Minibatch Loss= 0.2085, Training Accuracy= 0.9429, Minibatch error= 5.7%
# 2017-11-06 17:59:21,462 Iter 52, Minibatch Loss= 0.2132, Training Accuracy= 0.9411, Minibatch error= 5.9%
# 2017-11-06 17:59:30,788 Iter 54, Minibatch Loss= 0.2360, Training Accuracy= 0.9321, Minibatch error= 6.8%
# 2017-11-06 17:59:38,976 Iter 56, Minibatch Loss= 0.2348, Training Accuracy= 0.9321, Minibatch error= 6.8%
# 2017-11-06 17:59:47,544 Iter 58, Minibatch Loss= 0.1983, Training Accuracy= 0.9464, Minibatch error= 5.4%
# 2017-11-06 17:59:56,045 Iter 60, Minibatch Loss= 0.2105, Training Accuracy= 0.9412, Minibatch error= 5.9%
# 2017-11-06 18:00:04,394 Iter 62, Minibatch Loss= 0.2229, Training Accuracy= 0.9358, Minibatch error= 6.4%
# 2017-11-06 18:00:07,044 Epoch 1, Average loss: 0.2239, learning rate: 0.0010
# 2017-11-06 18:00:09,097 Verification error= 6.0%, loss= 0.2099
# 2017-11-06 18:00:25,445 Iter 64, Minibatch Loss= 0.2006, Training Accuracy= 0.9429, Minibatch error= 5.7%
# 2017-11-06 18:00:33,436 Iter 66, Minibatch Loss= 0.2236, Training Accuracy= 0.9340, Minibatch error= 6.6%
# 2017-11-06 18:00:41,565 Iter 68, Minibatch Loss= 0.2031, Training Accuracy= 0.9411, Minibatch error= 5.9%
# 2017-11-06 18:00:48,860 Iter 70, Minibatch Loss= 0.2004, Training Accuracy= 0.9412, Minibatch error= 5.9%
# 2017-11-06 18:00:57,827 Iter 72, Minibatch Loss= 0.2037, Training Accuracy= 0.9393, Minibatch error= 6.1%
# 2017-11-06 18:01:06,518 Iter 74, Minibatch Loss= 0.1827, Training Accuracy= 0.9447, Minibatch error= 5.5%
# 2017-11-06 18:01:14,560 Iter 76, Minibatch Loss= 0.1997, Training Accuracy= 0.9393, Minibatch error= 6.1%
# 2017-11-06 18:01:23,150 Iter 78, Minibatch Loss= 0.1858, Training Accuracy= 0.9429, Minibatch error= 5.7%
# 2017-11-06 18:01:32,125 Iter 80, Minibatch Loss= 0.1790, Training Accuracy= 0.9447, Minibatch error= 5.5%
# 2017-11-06 18:01:39,669 Iter 82, Minibatch Loss= 0.1720, Training Accuracy= 0.9464, Minibatch error= 5.4%
# 2017-11-06 18:01:48,626 Iter 84, Minibatch Loss= 0.1855, Training Accuracy= 0.9411, Minibatch error= 5.9%
# 2017-11-06 18:01:57,033 Iter 86, Minibatch Loss= 0.1670, Training Accuracy= 0.9464, Minibatch error= 5.4%
# 2017-11-06 18:02:05,016 Iter 88, Minibatch Loss= 0.2068, Training Accuracy= 0.9321, Minibatch error= 6.8%
# 2017-11-06 18:02:14,847 Iter 90, Minibatch Loss= 0.1813, Training Accuracy= 0.9429, Minibatch error= 5.7%
# 2017-11-06 18:02:23,174 Iter 92, Minibatch Loss= 0.1879, Training Accuracy= 0.9393, Minibatch error= 6.1%
# 2017-11-06 18:02:31,191 Iter 94, Minibatch Loss= 0.1944, Training Accuracy= 0.9358, Minibatch error= 6.4%
# 2017-11-06 18:02:34,090 Epoch 2, Average loss: 0.2020, learning rate: 0.0010
# 2017-11-06 18:02:36,472 Verification error= 6.0%, loss= 0.1821
# 2017-11-06 18:02:54,483 Iter 96, Minibatch Loss= 0.1816, Training Accuracy= 0.9411, Minibatch error= 5.9%
# 2017-11-06 18:03:02,830 Iter 98, Minibatch Loss= 0.1728, Training Accuracy= 0.9429, Minibatch error= 5.7%
# 2017-11-06 18:03:11,464 Iter 100, Minibatch Loss= 0.1586, Training Accuracy= 0.9464, Minibatch error= 5.4%
# 2017-11-06 18:03:19,911 Iter 102, Minibatch Loss= 0.1636, Training Accuracy= 0.9447, Minibatch error= 5.5%
# 2017-11-06 18:03:27,844 Iter 104, Minibatch Loss= 0.1716, Training Accuracy= 0.9429, Minibatch error= 5.7%
# 2017-11-06 18:03:36,062 Iter 106, Minibatch Loss= 0.1994, Training Accuracy= 0.9321, Minibatch error= 6.8%
# 2017-11-06 18:03:44,388 Iter 108, Minibatch Loss= 0.1613, Training Accuracy= 0.9447, Minibatch error= 5.5%
# 2017-11-06 18:03:52,039 Iter 110, Minibatch Loss= 0.1545, Training Accuracy= 0.9464, Minibatch error= 5.4%
# 2017-11-06 18:03:59,729 Iter 112, Minibatch Loss= 0.1733, Training Accuracy= 0.9412, Minibatch error= 5.9%
# 2017-11-06 18:04:08,729 Iter 114, Minibatch Loss= 0.1798, Training Accuracy= 0.9393, Minibatch error= 6.1%
# 2017-11-06 18:04:16,393 Iter 116, Minibatch Loss= 0.1620, Training Accuracy= 0.9429, Minibatch error= 5.7%
# 2017-11-06 18:04:25,131 Iter 118, Minibatch Loss= 0.1776, Training Accuracy= 0.9393, Minibatch error= 6.1%
# 2017-11-06 18:04:33,101 Iter 120, Minibatch Loss= 0.1678, Training Accuracy= 0.9411, Minibatch error= 5.9%
# 2017-11-06 18:04:40,896 Iter 122, Minibatch Loss= 0.1921, Training Accuracy= 0.9321, Minibatch error= 6.8%
# 2017-11-06 18:04:49,251 Iter 124, Minibatch Loss= 0.1553, Training Accuracy= 0.9429, Minibatch error= 5.7%
# 2017-11-06 18:04:58,694 Iter 126, Minibatch Loss= 0.1391, Training Accuracy= 0.9464, Minibatch error= 5.4%
# 2017-11-06 18:05:01,667 Epoch 3, Average loss: 0.1815, learning rate: 0.0010
# 2017-11-06 18:05:04,097 Verification error= 6.0%, loss= 0.1667
# 2017-11-06 18:05:23,274 Iter 128, Minibatch Loss= 0.1720, Training Accuracy= 0.9340, Minibatch error= 6.6%
# 2017-11-06 18:05:31,410 Iter 130, Minibatch Loss= 0.1449, Training Accuracy= 0.9412, Minibatch error= 5.9%
# 2017-11-06 18:05:41,666 Iter 132, Minibatch Loss= 0.2275, Training Accuracy= 0.9429, Minibatch error= 5.7%
# 2017-11-06 18:05:51,535 Iter 134, Minibatch Loss= 0.2177, Training Accuracy= 0.9447, Minibatch error= 5.5%
# 2017-11-06 18:05:59,455 Iter 136, Minibatch Loss= 0.1400, Training Accuracy= 0.9429, Minibatch error= 5.7%
# 2017-11-06 18:06:08,225 Iter 138, Minibatch Loss= 0.1513, Training Accuracy= 0.9447, Minibatch error= 5.5%
# 2017-11-06 18:06:17,054 Iter 140, Minibatch Loss= 0.1841, Training Accuracy= 0.9321, Minibatch error= 6.8%
# 2017-11-06 18:06:26,122 Iter 142, Minibatch Loss= 0.1994, Training Accuracy= 0.9340, Minibatch error= 6.6%
# 2017-11-06 18:06:35,067 Iter 144, Minibatch Loss= 0.1821, Training Accuracy= 0.9358, Minibatch error= 6.4%
# 2017-11-06 18:06:44,432 Iter 146, Minibatch Loss= 0.1300, Training Accuracy= 0.9429, Minibatch error= 5.7%
# 2017-11-06 18:06:52,054 Iter 148, Minibatch Loss= 0.1549, Training Accuracy= 0.9321, Minibatch error= 6.8%
# 2017-11-06 18:07:00,858 Iter 150, Minibatch Loss= 0.1255, Training Accuracy= 0.9358, Minibatch error= 6.4%
# 2017-11-06 18:07:09,562 Iter 152, Minibatch Loss= 0.0970, Training Accuracy= 0.9340, Minibatch error= 6.6%
# 2017-11-06 18:07:17,796 Iter 154, Minibatch Loss= 0.1627, Training Accuracy= 0.9447, Minibatch error= 5.5%
# 2017-11-06 18:07:26,648 Iter 156, Minibatch Loss= 0.2441, Training Accuracy= 0.9340, Minibatch error= 6.6%
# 2017-11-06 18:07:35,796 Iter 158, Minibatch Loss= 0.1250, Training Accuracy= 0.9393, Minibatch error= 6.1%
# 2017-11-06 18:07:38,937 Epoch 4, Average loss: 0.1597, learning rate: 0.0010
# 2017-11-06 18:07:41,053 Verification error= 6.0%, loss= 0.0825
# 2017-11-06 18:08:01,388 Iter 160, Minibatch Loss= 0.0769, Training Accuracy= 0.9411, Minibatch error= 5.9%
# 2017-11-06 18:08:09,459 Iter 162, Minibatch Loss= 0.0702, Training Accuracy= 0.9412, Minibatch error= 5.9%
# 2017-11-06 18:08:18,698 Iter 164, Minibatch Loss= 0.0534, Training Accuracy= 0.9464, Minibatch error= 5.4%
# 2017-11-06 18:08:27,597 Iter 166, Minibatch Loss= 0.0490, Training Accuracy= 0.9447, Minibatch error= 5.5%
# 2017-11-06 18:08:36,005 Iter 168, Minibatch Loss= 0.0642, Training Accuracy= 0.9427, Minibatch error= 5.7%
# 2017-11-06 18:08:45,507 Iter 170, Minibatch Loss= 0.0450, Training Accuracy= 0.9482, Minibatch error= 5.2%
# 2017-11-06 18:08:53,279 Iter 172, Minibatch Loss= 0.0385, Training Accuracy= 0.9683, Minibatch error= 3.2%
# 2017-11-06 18:09:01,923 Iter 174, Minibatch Loss= 0.0217, Training Accuracy= 0.9899, Minibatch error= 1.0%
# 2017-11-06 18:09:11,158 Iter 176, Minibatch Loss= 0.0179, Training Accuracy= 0.9903, Minibatch error= 1.0%
# 2017-11-06 18:09:18,810 Iter 178, Minibatch Loss= 0.0154, Training Accuracy= 0.9953, Minibatch error= 0.5%
# 2017-11-06 18:09:27,321 Iter 180, Minibatch Loss= 0.0239, Training Accuracy= 0.9931, Minibatch error= 0.7%
# 2017-11-06 18:09:34,904 Iter 182, Minibatch Loss= 0.0191, Training Accuracy= 0.9929, Minibatch error= 0.7%
# 2017-11-06 18:09:43,701 Iter 184, Minibatch Loss= 0.0132, Training Accuracy= 0.9925, Minibatch error= 0.7%
# 2017-11-06 18:09:54,027 Iter 186, Minibatch Loss= 0.0130, Training Accuracy= 0.9926, Minibatch error= 0.7%
# 2017-11-06 18:10:01,640 Iter 188, Minibatch Loss= 0.0142, Training Accuracy= 0.9964, Minibatch error= 0.4%
# 2017-11-06 18:10:10,153 Iter 190, Minibatch Loss= 0.0173, Training Accuracy= 0.9910, Minibatch error= 0.9%
# 2017-11-06 18:10:13,177 Epoch 5, Average loss: 0.0422, learning rate: 0.0010
# 2017-11-06 18:10:15,076 Verification error= 0.7%, loss= 0.0190
# 2017-11-06 18:10:35,399 Iter 192, Minibatch Loss= 0.0128, Training Accuracy= 0.9954, Minibatch error= 0.5%
# 2017-11-06 18:10:42,991 Iter 194, Minibatch Loss= 0.0117, Training Accuracy= 0.9932, Minibatch error= 0.7%
# 2017-11-06 18:10:53,358 Iter 196, Minibatch Loss= 0.0099, Training Accuracy= 0.9955, Minibatch error= 0.4%
# 2017-11-06 18:11:00,575 Iter 198, Minibatch Loss= 0.0247, Training Accuracy= 0.9908, Minibatch error= 0.9%
# 2017-11-06 18:11:09,705 Iter 200, Minibatch Loss= 0.0207, Training Accuracy= 0.9921, Minibatch error= 0.8%
# 2017-11-06 18:11:19,139 Iter 202, Minibatch Loss= 0.0135, Training Accuracy= 0.9922, Minibatch error= 0.8%
# 2017-11-06 18:11:26,868 Iter 204, Minibatch Loss= 0.0267, Training Accuracy= 0.9903, Minibatch error= 1.0%
# 2017-11-06 18:11:35,631 Iter 206, Minibatch Loss= 0.0121, Training Accuracy= 0.9934, Minibatch error= 0.7%
# 2017-11-06 18:11:45,085 Iter 208, Minibatch Loss= 0.0184, Training Accuracy= 0.9915, Minibatch error= 0.8%
# 2017-11-06 18:11:53,418 Iter 210, Minibatch Loss= 0.0284, Training Accuracy= 0.9890, Minibatch error= 1.1%
# 2017-11-06 18:12:02,070 Iter 212, Minibatch Loss= 0.0154, Training Accuracy= 0.9926, Minibatch error= 0.7%
# 2017-11-06 18:12:11,566 Iter 214, Minibatch Loss= 0.0112, Training Accuracy= 0.9934, Minibatch error= 0.7%
# 2017-11-06 18:12:21,106 Iter 216, Minibatch Loss= 0.0120, Training Accuracy= 0.9960, Minibatch error= 0.4%
# 2017-11-06 18:12:29,028 Iter 218, Minibatch Loss= 0.0111, Training Accuracy= 0.9961, Minibatch error= 0.4%
# 2017-11-06 18:12:38,228 Iter 220, Minibatch Loss= 0.0127, Training Accuracy= 0.9964, Minibatch error= 0.4%
# 2017-11-06 18:12:46,511 Iter 222, Minibatch Loss= 0.0213, Training Accuracy= 0.9902, Minibatch error= 1.0%
# 2017-11-06 18:12:49,334 Epoch 6, Average loss: 0.0150, learning rate: 0.0010
# 2017-11-06 18:12:51,838 Verification error= 0.7%, loss= 0.0176
# 2017-11-06 18:13:12,546 Iter 224, Minibatch Loss= 0.0107, Training Accuracy= 0.9955, Minibatch error= 0.5%
# 2017-11-06 18:13:22,186 Iter 226, Minibatch Loss= 0.0198, Training Accuracy= 0.9928, Minibatch error= 0.7%
# 2017-11-06 18:13:30,705 Iter 228, Minibatch Loss= 0.0469, Training Accuracy= 0.9869, Minibatch error= 1.3%
# 2017-11-06 18:13:38,994 Iter 230, Minibatch Loss= 0.0184, Training Accuracy= 0.9909, Minibatch error= 0.9%
# 2017-11-06 18:13:48,146 Iter 232, Minibatch Loss= 0.0119, Training Accuracy= 0.9928, Minibatch error= 0.7%
# 2017-11-06 18:13:55,962 Iter 234, Minibatch Loss= 0.0139, Training Accuracy= 0.9943, Minibatch error= 0.6%
# 2017-11-06 18:14:04,407 Iter 236, Minibatch Loss= 0.0108, Training Accuracy= 0.9940, Minibatch error= 0.6%
# 2017-11-06 18:14:13,388 Iter 238, Minibatch Loss= 0.0136, Training Accuracy= 0.9940, Minibatch error= 0.6%
# 2017-11-06 18:14:20,622 Iter 240, Minibatch Loss= 0.0116, Training Accuracy= 0.9945, Minibatch error= 0.5%
# 2017-11-06 18:14:28,842 Iter 242, Minibatch Loss= 0.0126, Training Accuracy= 0.9949, Minibatch error= 0.5%
# 2017-11-06 18:14:38,898 Iter 244, Minibatch Loss= 0.0397, Training Accuracy= 0.9863, Minibatch error= 1.4%
# 2017-11-06 18:14:47,053 Iter 246, Minibatch Loss= 0.0101, Training Accuracy= 0.9959, Minibatch error= 0.4%
# 2017-11-06 18:14:55,699 Iter 248, Minibatch Loss= 0.0091, Training Accuracy= 0.9954, Minibatch error= 0.5%
# 2017-11-06 18:15:04,082 Iter 250, Minibatch Loss= 0.0124, Training Accuracy= 0.9929, Minibatch error= 0.7%
# 2017-11-06 18:15:11,982 Iter 252, Minibatch Loss= 0.0142, Training Accuracy= 0.9943, Minibatch error= 0.6%
# 2017-11-06 18:15:21,216 Iter 254, Minibatch Loss= 0.0130, Training Accuracy= 0.9952, Minibatch error= 0.5%
# 2017-11-06 18:15:24,236 Epoch 7, Average loss: 0.0153, learning rate: 0.0010
# 2017-11-06 18:15:26,282 Verification error= 0.5%, loss= 0.0125
# 2017-11-06 18:15:48,510 Iter 256, Minibatch Loss= 0.0115, Training Accuracy= 0.9938, Minibatch error= 0.6%
# 2017-11-06 18:15:56,250 Iter 258, Minibatch Loss= 0.0114, Training Accuracy= 0.9964, Minibatch error= 0.4%
# 2017-11-06 18:16:04,649 Iter 260, Minibatch Loss= 0.0121, Training Accuracy= 0.9956, Minibatch error= 0.4%
# 2017-11-06 18:16:13,956 Iter 262, Minibatch Loss= 0.0216, Training Accuracy= 0.9905, Minibatch error= 0.9%
# 2017-11-06 18:16:21,522 Iter 264, Minibatch Loss= 0.0341, Training Accuracy= 0.9877, Minibatch error= 1.2%
# 2017-11-06 18:16:29,457 Iter 266, Minibatch Loss= 0.0212, Training Accuracy= 0.9922, Minibatch error= 0.8%
# 2017-11-06 18:16:38,450 Iter 268, Minibatch Loss= 0.0092, Training Accuracy= 0.9957, Minibatch error= 0.4%
# 2017-11-06 18:16:46,492 Iter 270, Minibatch Loss= 0.0128, Training Accuracy= 0.9964, Minibatch error= 0.4%
# 2017-11-06 18:16:56,213 Iter 272, Minibatch Loss= 0.0106, Training Accuracy= 0.9965, Minibatch error= 0.4%
# 2017-11-06 18:17:04,783 Iter 274, Minibatch Loss= 0.0117, Training Accuracy= 0.9951, Minibatch error= 0.5%
# 2017-11-06 18:17:13,587 Iter 276, Minibatch Loss= 0.0101, Training Accuracy= 0.9964, Minibatch error= 0.4%
# 2017-11-06 18:17:23,320 Iter 278, Minibatch Loss= 0.0131, Training Accuracy= 0.9934, Minibatch error= 0.7%
# 2017-11-06 18:17:31,723 Iter 280, Minibatch Loss= 0.0096, Training Accuracy= 0.9959, Minibatch error= 0.4%
# 2017-11-06 18:17:42,439 Iter 282, Minibatch Loss= 0.0174, Training Accuracy= 0.9934, Minibatch error= 0.7%
# 2017-11-06 18:17:52,836 Iter 284, Minibatch Loss= 0.0243, Training Accuracy= 0.9892, Minibatch error= 1.1%
# 2017-11-06 18:18:00,820 Iter 286, Minibatch Loss= 0.0169, Training Accuracy= 0.9927, Minibatch error= 0.7%
# 2017-11-06 18:18:03,749 Epoch 8, Average loss: 0.0144, learning rate: 0.0010
# 2017-11-06 18:18:05,938 Verification error= 0.6%, loss= 0.0128
# 2017-11-06 18:18:28,166 Iter 288, Minibatch Loss= 0.0119, Training Accuracy= 0.9955, Minibatch error= 0.4%
# 2017-11-06 18:18:37,488 Iter 290, Minibatch Loss= 0.0101, Training Accuracy= 0.9959, Minibatch error= 0.4%
# 2017-11-06 18:18:48,485 Iter 292, Minibatch Loss= 0.0098, Training Accuracy= 0.9960, Minibatch error= 0.4%
# 2017-11-06 18:18:56,596 Iter 294, Minibatch Loss= 0.0120, Training Accuracy= 0.9964, Minibatch error= 0.4%
# 2017-11-06 18:19:05,802 Iter 296, Minibatch Loss= 0.0112, Training Accuracy= 0.9949, Minibatch error= 0.5%
# 2017-11-06 18:19:15,352 Iter 298, Minibatch Loss= 0.0115, Training Accuracy= 0.9935, Minibatch error= 0.7%
# 2017-11-06 18:19:23,172 Iter 300, Minibatch Loss= 0.0122, Training Accuracy= 0.9964, Minibatch error= 0.4%
# 2017-11-06 18:19:33,031 Iter 302, Minibatch Loss= 0.0102, Training Accuracy= 0.9955, Minibatch error= 0.5%
# 2017-11-06 18:19:41,625 Iter 304, Minibatch Loss= 0.0182, Training Accuracy= 0.9915, Minibatch error= 0.8%
# 2017-11-06 18:19:49,374 Iter 306, Minibatch Loss= 0.0140, Training Accuracy= 0.9931, Minibatch error= 0.7%
# 2017-11-06 18:19:58,951 Iter 308, Minibatch Loss= 0.0126, Training Accuracy= 0.9952, Minibatch error= 0.5%
# 2017-11-06 18:20:07,634 Iter 310, Minibatch Loss= 0.0123, Training Accuracy= 0.9926, Minibatch error= 0.7%
# 2017-11-06 18:20:16,075 Iter 312, Minibatch Loss= 0.0119, Training Accuracy= 0.9929, Minibatch error= 0.7%
# 2017-11-06 18:20:25,078 Iter 314, Minibatch Loss= 0.0157, Training Accuracy= 0.9941, Minibatch error= 0.6%
# 2017-11-06 18:20:34,731 Iter 316, Minibatch Loss= 0.0417, Training Accuracy= 0.9861, Minibatch error= 1.4%
# 2017-11-06 18:20:42,863 Iter 318, Minibatch Loss= 0.0170, Training Accuracy= 0.9920, Minibatch error= 0.8%
# 2017-11-06 18:20:45,805 Epoch 9, Average loss: 0.0154, learning rate: 0.0010
# 2017-11-06 18:20:48,289 Verification error= 0.5%, loss= 0.0132
# 2017-11-06 18:21:09,249 Optimization Finished!

# %%
x_test, y_test = data_provider(1)

# %%
prediction = net.predict("./out/model.cpkt", x_test)
# Out:
# INFO:tensorflow:Restoring parameters from ./out/model.cpkt
# 2017-11-06 18:22:28,833 Restoring parameters from ./out/model.cpkt
# 2017-11-06 18:22:30,622 Model restored from file: ./out/model.cpkt

# %%
fig, ax = plt.subplots(1, 3, sharex=True, sharey=True, figsize=(12,5))
ax[0].imshow(x_test[0,...,0], aspect="auto")
ax[1].imshow(y_test[0,...,1], aspect="auto")
mask = prediction[0,...,1] > 0.9
ax[2].imshow(mask, aspect="auto")
ax[0].set_title("Input")
ax[1].set_title("Ground truth")
ax[2].set_title("Prediction")
fig.tight_layout()

plt.show()

# %%
unet.error_rate(prediction, util.crop_to_shape(y_test, prediction.shape))
# Out:
# 0.51884139482564251

# %%
img = util.combine_img_prediction(x_test,y_test,prediction)
#util.save_image(img, "/Users/cesare.chung/int/mura_problem.png")
util.save_image(img, "D:/Cesare/tf_UNET_int/mura_problem.png")
